# %% [markdown]
# ## Imports

# %%
# DATA MANIPULATION
import numpy as np

# DATA VISUALIZATION
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import KFold, train_test_split
from sklearn.preprocessing import StandardScaler

# BLOB DATASET
from sklearn.datasets import make_blobs

# KERAS
from tensorflow.keras import models, layers, regularizers
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
# Out:
# 2023-05-20 15:22:16.829448: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # How to Properly Prevent Overfitting

# %% [markdown]
# 🎯 **Goals of this challenge**
# - **`Cross Validate`** a Deep Learning Model
# - Give a **`Validation Set`** to the model
# - Apply two techniques to prevent overfitting:
#     - Use the **`Early Stopping`** criterion to prevent the Neural network from over-learning / over-fitting
#     - **`Regularize`** your network
# - Analyze the **`impact of the batch size and the number of epochs`** on the training of a Neural Network

# %% [markdown]
# ## Data - the `blobs` Dataset

# %% [markdown]
# ### Generating a Blobs Dataset
#
# First, let's generate some data using the [`make_blobs`](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_blobs.html) function from Scikit-Learn
#
# Generate 2000 samples with 10 features each; there should be 8 classes of blobs (`centers` argument) with `cluster_std` equal to 7.

# %%
# YOUR CODE HERE
from sklearn.datasets import make_blobs
X, y = make_blobs(n_samples=2000,n_features=10,centers=8,cluster_std=7)

# %% [markdown]
# ### Visualizing the Dataset
#
# All your samples have 10 features. Plot one of the dimensions against another.

# %%
# YOUR CODE HERE
plt.plot(X[0])
plt.plot(X[1])

# %% [markdown]
# ### Encoding your Categorical Target
#
# Use the 📚 [**to_categorical()**](https://www.tensorflow.org/api_docs/python/tf/keras/utils/to_categorical) function to convert `y` to `y_cat`, which is the categorical representation of `y` with **One-Hot encoded** columns.

# %%
# YOUR CODE HERE
y_cat = to_categorical(y)

# %% [markdown]
# ## (1) Cross-Validation in Deep Learning
#
# 👩🏻‍🏫 In a previous challenge, we split the dataset into a training set and a testing set at the beginning of the notebook. Then, we started to build different models which were trained on the training set and evaluated on the testing set.
#
# So, at the end of the day, we used the testing set every time we evaluated our models and different hyperparameters. This is normal: we always train on the training set and we evaluate on the testing set.
#
# However, we selected our "best model" based on the score of each model. In other words, we _used_ the test set to select our best model, which means there was ❗️ `data leakage` ❗️
#
# 🤔 **what should we do?**
#
# - A first good practice is to avoid using `random_state` or any deterministic separation between your training and testing sets. In that case, your testing set will change every time you re-run your notebook. This is far from being sufficient, though
# - To compare models properly, you have to run a cross-validation, a 10-fold split, for instance
#
# 🧐 If you look at [sklearn.model_selection.cross_validate](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_validate.html), this Cross -Validation tool is designed for Machine Learning algorithms implemented in Scikit Learn, whereas we have been creating and using Neural Networks from Tensorflow/Keras.
#
# 🔥 Let's discover how to **Cross-validate a Neural Network**.

# %% [markdown]
# ### Designing a Neural Network
#
# First, write a function that generates a Neural Network with 3 layers:
#
# <u>Architecture</u>
# - an **input layer** with 25 neurons, the `relu` activation function and the appropriate `input_dim`
# - a **hidden layer** with 10 neurons and the `relu` activation function.
# - a **predictive layer** that is suited to the problem at hand (*multiclass classification*)
#
# <u>Compilation</u>
#
# The function should include a compilation method with:
# - the *categorical_crossentropy* loss
# - the *Adam* optimizer
# - the *accuracy* metric

# %%
X.shape
# Out:
# (2000, 10)

# %%
from tensorflow.keras import regularizers, Sequential, layers

def initialize_model():
    
    model = Sequential()
    model.add(layers.Dense(25, activation='relu', input_dim=10))
    model.add(layers.Dense(10, activation='relu'))
    model.add(layers.Dense(8, activation='softmax'))
    
    model.compile(
    optimizer='adam',
    loss='categorical_crossentropy', 
    metrics = 'accuracy')
    
    return model

# %% [markdown]
# ### Cross-Validating the Neural Net
#
# 🧑🏻‍💻 Write a _loop_ using the [K-Fold](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.KFold.html) function from Scikit-Learn.
#
# * ✂️ Choose 10 splits to fit your model on the training data
# * 🧪 Evaluate your model on the testing data, and store the results of the evaluation into a `results` variable.
#
# _Hints_:
# * ⚖️ Do not forget to standardize your training data before fitting the NN
# * 👌 150 epochs should be sufficient for a first approximation
# * 🤝 As this is your first Deep Learning Cross-Validation, you are guided; just uncomment the following cell and follow the steps
# * ⏳ Notice that we added `%% time` at the beginning of this Jupyter Notebook cell to display its running time, and we encourage you to do so whenever you run expensive computations

# %%
model = initialize_model()
model.fit(X,y_cat)
score = model.evaluate(X,y_cat)
#score[#loss, #accuracy]
# Out:
# 63/63 [==============================] - 1s 4ms/step - loss: 3.4543 - accuracy: 0.1240
# 63/63 [==============================] - 0s 3ms/step - loss: 2.3426 - accuracy: 0.1845
# [2.3425846099853516, 0.18449999392032623]

# %%
# %%time

    kf = KFold(n_splits=10)
    kf.get_n_splits(X)
    results = []
    for train_index, test_index in kf.split(X):
    # Split the data into train and test
        X_train = X[train_index]
        y_train = y_cat[train_index]
        X_test = X[test_index]
        y_test = y_cat[test_index]
        
         # Scaling your data
        
        scaler = StandardScaler()
        X_scaled = scaler.fit_transform(X_train)
        X_test_scaled = scaler.transform(X_test)
        
         # Initialize the model
        model = initialize_model()

         # Fit the model on the train data
        model.fit(X_train,y_train,epochs=150)
         # Evaluate the model on the test data
        score = model.evaluate(X_test,y_test)
        results.append(score[1])
    results
# Out:
# Epoch 1/150
# 57/57 [==============================] - 2s 5ms/step - loss: 3.5281 - accuracy: 0.1194
# Epoch 2/150
# 57/57 [==============================] - 1s 12ms/step - loss: 1.8900 - accuracy: 0.2889
# Epoch 3/150
# 57/57 [==============================] - 1s 13ms/step - loss: 1.4218 - accuracy: 0.4783
# Epoch 4/150
# 57/57 [==============================] - 0s 5ms/step - loss: 1.1692 - accuracy: 0.5811
# Epoch 5/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.9999 - accuracy: 0.6500
# Epoch 6/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.8775 - accuracy: 0.6972
# Epoch 7/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.7850 - accuracy: 0.7372
# Epoch 8/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.7143 - accuracy: 0.7672
# Epoch 9/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.6554 - accuracy: 0.7900
# Epoch 10/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.6181 - accuracy: 0.8117
# Epoch 11/150
# 57/57 [==============================] - 0s 6ms/step - loss: 0.5816 - accuracy: 0.8200
# Epoch 12/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.5569 - accuracy: 0.8228
# Epoch 13/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.5358 - accuracy: 0.8283
# Epoch 14/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.5170 - accuracy: 0.8311
# Epoch 15/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.5013 - accuracy: 0.8383
# Epoch 16/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.4866 - accuracy: 0.8389
# Epoch 17/150
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4767 - accuracy: 0.8394
# Epoch 18/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.4653 - accuracy: 0.8461
# Epoch 19/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.4541 - accuracy: 0.8483
# Epoch 20/150
# 57/57 [==============================] - 0s 8ms/step - loss: 0.4448 - accuracy: 0.8489
# Epoch 21/150
# 57/57 [==============================] - 0s 9ms/step - loss: 0.4372 - accuracy: 0.8522
# Epoch 22/150
# 57/57 [==============================] - 1s 5ms/step - loss: 0.4305 - accuracy: 0.8550
# Epoch 23/150
# 57/57 [==============================] - 0s 6ms/step - loss: 0.4255 - accuracy: 0.8522
# Epoch 24/150
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4217 - accuracy: 0.8589
# Epoch 25/150
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4139 - accuracy: 0.8556
# Epoch 26/150
# 57/57 [==============================] - 0s 6ms/step - loss: 0.4107 - accuracy: 0.8589
# Epoch 27/150
# 57/57 [==============================] - 0s 9ms/step - loss: 0.4054 - accuracy: 0.8611
# Epoch 28/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.4041 - accuracy: 0.8583
# Epoch 29/150
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3957 - accuracy: 0.8589
# Epoch 30/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3916 - accuracy: 0.8672
# Epoch 31/150
# 57/57 [==============================] - 0s 7ms/step - loss: 0.3942 - accuracy: 0.8644
# Epoch 32/150
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3850 - accuracy: 0.8656
# Epoch 33/150
# 57/57 [==============================] - 0s 7ms/step - loss: 0.3846 - accuracy: 0.8633
# Epoch 34/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3811 - accuracy: 0.8633
# Epoch 35/150
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3791 - accuracy: 0.8683
# Epoch 36/150
# 57/57 [==============================] - 1s 12ms/step - loss: 0.3774 - accuracy: 0.8683
# Epoch 37/150
# 57/57 [==============================] - 0s 7ms/step - loss: 0.3735 - accuracy: 0.8694
# Epoch 38/150
# 57/57 [==============================] - 1s 11ms/step - loss: 0.3703 - accuracy: 0.8728
# Epoch 39/150
# 57/57 [==============================] - 0s 8ms/step - loss: 0.3684 - accuracy: 0.8689
# Epoch 40/150
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3674 - accuracy: 0.8700
# Epoch 41/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3623 - accuracy: 0.8717
# Epoch 42/150
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3627 - accuracy: 0.8672
# Epoch 43/150
# 57/57 [==============================] - 0s 8ms/step - loss: 0.3592 - accuracy: 0.8733
# Epoch 44/150
# 57/57 [==============================] - 0s 7ms/step - loss: 0.3571 - accuracy: 0.8744
# Epoch 45/150
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3563 - accuracy: 0.8717
# Epoch 46/150
# 57/57 [==============================] - 1s 16ms/step - loss: 0.3546 - accuracy: 0.8706
# Epoch 47/150
# 57/57 [==============================] - 1s 13ms/step - loss: 0.3508 - accuracy: 0.8767
# Epoch 48/150
# 57/57 [==============================] - 1s 18ms/step - loss: 0.3504 - accuracy: 0.8778
# Epoch 49/150
# 57/57 [==============================] - 0s 6ms/step - loss: 0.3472 - accuracy: 0.8750
# Epoch 50/150
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3489 - accuracy: 0.8728
# Epoch 51/150
# 57/57 [==============================] - 0s 8ms/step - loss: 0.3462 - accuracy: 0.8772
# Epoch 52/150
# 57/57 [==============================] - 0s 8ms/step - loss: 0.3437 - accuracy: 0.8783
# Epoch 53/150
# 57/57 [==============================] - 1s 11ms/step - loss: 0.3428 - accuracy: 0.8794
# Epoch 54/150
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3391 - accuracy: 0.8800
# Epoch 55/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3388 - accuracy: 0.8750
# Epoch 56/150
# 57/57 [==============================] - 1s 17ms/step - loss: 0.3386 - accuracy: 0.8817
# Epoch 57/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3350 - accuracy: 0.8856
# Epoch 58/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3323 - accuracy: 0.8811
# Epoch 59/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3331 - accuracy: 0.8789
# Epoch 60/150
# 57/57 [==============================] - 0s 8ms/step - loss: 0.3308 - accuracy: 0.8783
# Epoch 61/150
# 57/57 [==============================] - 1s 17ms/step - loss: 0.3284 - accuracy: 0.8811
# Epoch 62/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3275 - accuracy: 0.8850
# Epoch 63/150
# 57/57 [==============================] - 0s 7ms/step - loss: 0.3297 - accuracy: 0.8844
# Epoch 64/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3269 - accuracy: 0.8794
# Epoch 65/150
# 57/57 [==============================] - 0s 7ms/step - loss: 0.3264 - accuracy: 0.8922
# Epoch 66/150
# 57/57 [==============================] - 1s 14ms/step - loss: 0.3259 - accuracy: 0.8844
# Epoch 67/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3212 - accuracy: 0.8889
# Epoch 68/150
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3220 - accuracy: 0.8889
# Epoch 69/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3205 - accuracy: 0.8867
# Epoch 70/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3183 - accuracy: 0.8883
# Epoch 71/150
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3180 - accuracy: 0.8794
# Epoch 72/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3183 - accuracy: 0.8900
# Epoch 73/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3152 - accuracy: 0.8828
# Epoch 74/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3127 - accuracy: 0.8933
# Epoch 75/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3147 - accuracy: 0.8889
# Epoch 76/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3126 - accuracy: 0.8861
# Epoch 77/150
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3110 - accuracy: 0.8878
# Epoch 78/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3083 - accuracy: 0.8889
# Epoch 79/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3089 - accuracy: 0.8889
# Epoch 80/150
# 57/57 [==============================] - 0s 6ms/step - loss: 0.3066 - accuracy: 0.8889
# Epoch 81/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3076 - accuracy: 0.8900
# Epoch 82/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3047 - accuracy: 0.8906
# Epoch 83/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3049 - accuracy: 0.8928
# Epoch 84/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3008 - accuracy: 0.8922
# Epoch 85/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3032 - accuracy: 0.8917
# Epoch 86/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3036 - accuracy: 0.8889
# Epoch 87/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2988 - accuracy: 0.8906
# Epoch 88/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2997 - accuracy: 0.8883
# Epoch 89/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3034 - accuracy: 0.8928
# Epoch 90/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2999 - accuracy: 0.8900
# Epoch 91/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2985 - accuracy: 0.8889
# Epoch 92/150
# 57/57 [==============================] - 0s 6ms/step - loss: 0.2992 - accuracy: 0.8917
# Epoch 93/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.2974 - accuracy: 0.8906
# Epoch 94/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2988 - accuracy: 0.8922
# Epoch 95/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2976 - accuracy: 0.8933
# Epoch 96/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.2941 - accuracy: 0.8972
# Epoch 97/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2946 - accuracy: 0.8961
# Epoch 98/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.2902 - accuracy: 0.8950
# Epoch 99/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2922 - accuracy: 0.8950
# Epoch 100/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2910 - accuracy: 0.8967
# Epoch 101/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2892 - accuracy: 0.8956
# Epoch 102/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.2884 - accuracy: 0.8972
# Epoch 103/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2900 - accuracy: 0.8939
# Epoch 104/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2866 - accuracy: 0.8983
# Epoch 105/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2880 - accuracy: 0.8972
# Epoch 106/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2851 - accuracy: 0.8944
# Epoch 107/150
# 57/57 [==============================] - 1s 11ms/step - loss: 0.2862 - accuracy: 0.8989
# Epoch 108/150
# 57/57 [==============================] - 0s 5ms/step - loss: 0.2842 - accuracy: 0.9033
# Epoch 109/150
# 57/57 [==============================] - 0s 6ms/step - loss: 0.2870 - accuracy: 0.8939
# Epoch 110/150
# 57/57 [==============================] - 0s 7ms/step - loss: 0.2853 - accuracy: 0.8989
# Epoch 111/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2834 - accuracy: 0.8978
# Epoch 112/150
# 57/57 [==============================] - 1s 15ms/step - loss: 0.2845 - accuracy: 0.8944
# Epoch 113/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.2841 - accuracy: 0.8989
# Epoch 114/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2824 - accuracy: 0.8983
# Epoch 115/150
# 57/57 [==============================] - 1s 9ms/step - loss: 0.2807 - accuracy: 0.8978
# Epoch 116/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.2814 - accuracy: 0.8978
# Epoch 117/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2789 - accuracy: 0.9044
# Epoch 118/150
# 57/57 [==============================] - 0s 7ms/step - loss: 0.2778 - accuracy: 0.9000
# Epoch 119/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.2767 - accuracy: 0.9006
# Epoch 120/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2771 - accuracy: 0.8994
# Epoch 121/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2773 - accuracy: 0.8972
# Epoch 122/150
# 57/57 [==============================] - 1s 17ms/step - loss: 0.2774 - accuracy: 0.8989
# Epoch 123/150
# 57/57 [==============================] - 0s 6ms/step - loss: 0.2791 - accuracy: 0.8933
# Epoch 124/150
# 57/57 [==============================] - 0s 5ms/step - loss: 0.2774 - accuracy: 0.8978
# Epoch 125/150
# 57/57 [==============================] - 1s 10ms/step - loss: 0.2763 - accuracy: 0.8922
# Epoch 126/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.2769 - accuracy: 0.8994
# Epoch 127/150
# 57/57 [==============================] - 0s 5ms/step - loss: 0.2748 - accuracy: 0.9028
# Epoch 128/150
# 57/57 [==============================] - 1s 11ms/step - loss: 0.2741 - accuracy: 0.8972
# Epoch 129/150
# 57/57 [==============================] - 0s 6ms/step - loss: 0.2716 - accuracy: 0.9022
# Epoch 130/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.2740 - accuracy: 0.9022
# Epoch 131/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.2756 - accuracy: 0.8994
# Epoch 132/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.2703 - accuracy: 0.9028
# Epoch 133/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.2701 - accuracy: 0.9028
# Epoch 134/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.2697 - accuracy: 0.9044
# Epoch 135/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2723 - accuracy: 0.9011
# Epoch 136/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2738 - accuracy: 0.8989
# Epoch 137/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2677 - accuracy: 0.9011
# Epoch 138/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2737 - accuracy: 0.8961
# Epoch 139/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.2696 - accuracy: 0.9017
# Epoch 140/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2695 - accuracy: 0.8994
# Epoch 141/150
# 57/57 [==============================] - 0s 5ms/step - loss: 0.2679 - accuracy: 0.9028
# Epoch 142/150
# 57/57 [==============================] - 0s 8ms/step - loss: 0.2643 - accuracy: 0.9028
# Epoch 143/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.2674 - accuracy: 0.9011
# Epoch 144/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2648 - accuracy: 0.9056
# Epoch 145/150
# 57/57 [==============================] - 1s 16ms/step - loss: 0.2663 - accuracy: 0.9067
# Epoch 146/150
# 57/57 [==============================] - 1s 12ms/step - loss: 0.2629 - accuracy: 0.9050
# Epoch 147/150
# 57/57 [==============================] - 0s 7ms/step - loss: 0.2642 - accuracy: 0.9033
# Epoch 148/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.2648 - accuracy: 0.9017
# Epoch 149/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2629 - accuracy: 0.9028
# Epoch 150/150
# 57/57 [==============================] - 0s 7ms/step - loss: 0.2645 - accuracy: 0.9039
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7204 - accuracy: 0.8000
# Epoch 1/150
# 57/57 [==============================] - 3s 5ms/step - loss: 2.7767 - accuracy: 0.1589
# Epoch 2/150
# 57/57 [==============================] - 0s 5ms/step - loss: 1.8978 - accuracy: 0.3289
# Epoch 3/150
# 57/57 [==============================] - 0s 7ms/step - loss: 1.6170 - accuracy: 0.4678
# Epoch 4/150
# 57/57 [==============================] - 0s 5ms/step - loss: 1.4313 - accuracy: 0.5339
# Epoch 5/150
# 57/57 [==============================] - 0s 5ms/step - loss: 1.2878 - accuracy: 0.5828
# Epoch 6/150
# 57/57 [==============================] - 0s 7ms/step - loss: 1.1703 - accuracy: 0.6306
# Epoch 7/150
# 57/57 [==============================] - 0s 6ms/step - loss: 1.0715 - accuracy: 0.6672
# Epoch 8/150
# 57/57 [==============================] - 0s 7ms/step - loss: 0.9646 - accuracy: 0.7089
# Epoch 9/150
# 57/57 [==============================] - 0s 8ms/step - loss: 0.8360 - accuracy: 0.7467
# Epoch 10/150
# 57/57 [==============================] - 0s 8ms/step - loss: 0.7353 - accuracy: 0.7739
# Epoch 11/150
# 57/57 [==============================] - 0s 5ms/step - loss: 0.6605 - accuracy: 0.7800
# Epoch 12/150
# 57/57 [==============================] - 0s 7ms/step - loss: 0.6125 - accuracy: 0.7994
# Epoch 13/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.5734 - accuracy: 0.8028
# Epoch 14/150
# 57/57 [==============================] - 0s 6ms/step - loss: 0.5505 - accuracy: 0.8072
# Epoch 15/150
# 57/57 [==============================] - 0s 6ms/step - loss: 0.5283 - accuracy: 0.8189
# Epoch 16/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.5125 - accuracy: 0.8228
# Epoch 17/150
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4958 - accuracy: 0.8300
# Epoch 18/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.4833 - accuracy: 0.8311
# Epoch 19/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.4764 - accuracy: 0.8344
# Epoch 20/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.4641 - accuracy: 0.8339
# Epoch 21/150
# 57/57 [==============================] - 1s 13ms/step - loss: 0.4568 - accuracy: 0.8411
# Epoch 22/150
# 57/57 [==============================] - 0s 6ms/step - loss: 0.4493 - accuracy: 0.8428
# Epoch 23/150
# 57/57 [==============================] - 0s 6ms/step - loss: 0.4464 - accuracy: 0.8428
# Epoch 24/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.4358 - accuracy: 0.8483
# Epoch 25/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.4327 - accuracy: 0.8494
# Epoch 26/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.4280 - accuracy: 0.8467
# Epoch 27/150
# 57/57 [==============================] - 1s 15ms/step - loss: 0.4210 - accuracy: 0.8511
# Epoch 28/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.4182 - accuracy: 0.8517
# Epoch 29/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.4113 - accuracy: 0.8550
# Epoch 30/150
# 57/57 [==============================] - 1s 20ms/step - loss: 0.4117 - accuracy: 0.8533
# Epoch 31/150
# 57/57 [==============================] - 0s 6ms/step - loss: 0.4061 - accuracy: 0.8539
# Epoch 32/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.4024 - accuracy: 0.8583
# Epoch 33/150
# 57/57 [==============================] - 0s 6ms/step - loss: 0.4050 - accuracy: 0.8533
# Epoch 34/150
# 57/57 [==============================] - 0s 7ms/step - loss: 0.3977 - accuracy: 0.8556
# Epoch 35/150
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3960 - accuracy: 0.8522
# Epoch 36/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3936 - accuracy: 0.8556
# Epoch 37/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3898 - accuracy: 0.8550
# Epoch 38/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3852 - accuracy: 0.8650
# Epoch 39/150
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3819 - accuracy: 0.8600
# Epoch 40/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3821 - accuracy: 0.8650
# Epoch 41/150
# 57/57 [==============================] - 1s 14ms/step - loss: 0.3779 - accuracy: 0.8672
# Epoch 42/150
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3763 - accuracy: 0.8606
# Epoch 43/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3749 - accuracy: 0.8606
# Epoch 44/150
# 57/57 [==============================] - 0s 8ms/step - loss: 0.3709 - accuracy: 0.8706
# Epoch 45/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3699 - accuracy: 0.8656
# Epoch 46/150
# 57/57 [==============================] - 0s 6ms/step - loss: 0.3687 - accuracy: 0.8661
# Epoch 47/150
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3643 - accuracy: 0.8694
# Epoch 48/150
# 57/57 [==============================] - 1s 12ms/step - loss: 0.3659 - accuracy: 0.8661
# Epoch 49/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3634 - accuracy: 0.8694
# Epoch 50/150
# 57/57 [==============================] - 1s 12ms/step - loss: 0.3586 - accuracy: 0.8733
# Epoch 51/150
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3585 - accuracy: 0.8717
# Epoch 52/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3604 - accuracy: 0.8728
# Epoch 53/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3531 - accuracy: 0.8761
# Epoch 54/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3527 - accuracy: 0.8694
# Epoch 55/150
# 57/57 [==============================] - 0s 6ms/step - loss: 0.3541 - accuracy: 0.8783
# Epoch 56/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3549 - accuracy: 0.8706
# Epoch 57/150
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3478 - accuracy: 0.8756
# Epoch 58/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3477 - accuracy: 0.8744
# Epoch 59/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3472 - accuracy: 0.8722
# Epoch 60/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3468 - accuracy: 0.8739
# Epoch 61/150
# 57/57 [==============================] - 0s 6ms/step - loss: 0.3431 - accuracy: 0.8767
# Epoch 62/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3431 - accuracy: 0.8750
# Epoch 63/150
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3385 - accuracy: 0.8761
# Epoch 64/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3430 - accuracy: 0.8772
# Epoch 65/150
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3380 - accuracy: 0.8833
# Epoch 66/150
# 57/57 [==============================] - 0s 6ms/step - loss: 0.3389 - accuracy: 0.8772
# Epoch 67/150
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3368 - accuracy: 0.8817
# Epoch 68/150
# 57/57 [==============================] - 0s 6ms/step - loss: 0.3336 - accuracy: 0.8800
# Epoch 69/150
# 57/57 [==============================] - 0s 9ms/step - loss: 0.3365 - accuracy: 0.8817
# Epoch 70/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3349 - accuracy: 0.8806
# Epoch 71/150
# 57/57 [==============================] - 0s 8ms/step - loss: 0.3324 - accuracy: 0.8811
# Epoch 72/150
# 57/57 [==============================] - 1s 17ms/step - loss: 0.3297 - accuracy: 0.8839
# Epoch 73/150
# 57/57 [==============================] - 0s 7ms/step - loss: 0.3303 - accuracy: 0.8844
# Epoch 74/150
# 57/57 [==============================] - 1s 20ms/step - loss: 0.3274 - accuracy: 0.8839
# Epoch 75/150
# 57/57 [==============================] - 0s 8ms/step - loss: 0.3281 - accuracy: 0.8839
# Epoch 76/150
# 57/57 [==============================] - 1s 24ms/step - loss: 0.3270 - accuracy: 0.8783
# Epoch 77/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3252 - accuracy: 0.8833
# Epoch 78/150
# 57/57 [==============================] - 1s 19ms/step - loss: 0.3210 - accuracy: 0.8850
# Epoch 79/150
# 57/57 [==============================] - 0s 6ms/step - loss: 0.3241 - accuracy: 0.8856
# Epoch 80/150
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3247 - accuracy: 0.8839
# Epoch 81/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3211 - accuracy: 0.8844
# Epoch 82/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3222 - accuracy: 0.8878
# Epoch 83/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3182 - accuracy: 0.8878
# Epoch 84/150
# 57/57 [==============================] - 0s 6ms/step - loss: 0.3185 - accuracy: 0.8844
# Epoch 85/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3179 - accuracy: 0.8861
# Epoch 86/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3174 - accuracy: 0.8856
# Epoch 87/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3144 - accuracy: 0.8867
# Epoch 88/150
# 57/57 [==============================] - 0s 6ms/step - loss: 0.3179 - accuracy: 0.8861
# Epoch 89/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3155 - accuracy: 0.8828
# Epoch 90/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3152 - accuracy: 0.8844
# Epoch 91/150
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3129 - accuracy: 0.8956
# Epoch 92/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3143 - accuracy: 0.8867
# Epoch 93/150
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3131 - accuracy: 0.8894
# Epoch 94/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3103 - accuracy: 0.8894
# Epoch 95/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3079 - accuracy: 0.8911
# Epoch 96/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3047 - accuracy: 0.8950
# Epoch 97/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3082 - accuracy: 0.8906
# Epoch 98/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3081 - accuracy: 0.8872
# Epoch 99/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3053 - accuracy: 0.8917
# Epoch 100/150
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3087 - accuracy: 0.8883
# Epoch 101/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3060 - accuracy: 0.8928
# Epoch 102/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3025 - accuracy: 0.8917
# Epoch 103/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3022 - accuracy: 0.8956
# Epoch 104/150
# 57/57 [==============================] - 1s 14ms/step - loss: 0.3039 - accuracy: 0.8889
# Epoch 105/150
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3005 - accuracy: 0.8894
# Epoch 106/150
# 57/57 [==============================] - 1s 21ms/step - loss: 0.3008 - accuracy: 0.8967
# Epoch 107/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.2994 - accuracy: 0.8933
# Epoch 108/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3023 - accuracy: 0.8889
# Epoch 109/150
# 57/57 [==============================] - 0s 6ms/step - loss: 0.2994 - accuracy: 0.8972
# Epoch 110/150
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3025 - accuracy: 0.8928
# Epoch 111/150
# 57/57 [==============================] - 0s 5ms/step - loss: 0.2978 - accuracy: 0.8883
# Epoch 112/150
# 57/57 [==============================] - 0s 5ms/step - loss: 0.2964 - accuracy: 0.8933
# Epoch 113/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2966 - accuracy: 0.8928
# Epoch 114/150
# 57/57 [==============================] - 1s 9ms/step - loss: 0.2954 - accuracy: 0.8944
# Epoch 115/150
# 57/57 [==============================] - 0s 8ms/step - loss: 0.2965 - accuracy: 0.8950
# Epoch 116/150
# 57/57 [==============================] - 1s 9ms/step - loss: 0.2970 - accuracy: 0.8917
# Epoch 117/150
# 57/57 [==============================] - 1s 13ms/step - loss: 0.2935 - accuracy: 0.8906
# Epoch 118/150
# 57/57 [==============================] - 0s 6ms/step - loss: 0.2920 - accuracy: 0.8933
# Epoch 119/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2975 - accuracy: 0.8906
# Epoch 120/150
# 57/57 [==============================] - 1s 11ms/step - loss: 0.2933 - accuracy: 0.8906
# Epoch 121/150
# 57/57 [==============================] - 0s 7ms/step - loss: 0.2961 - accuracy: 0.8894
# Epoch 122/150
# 57/57 [==============================] - 0s 6ms/step - loss: 0.2947 - accuracy: 0.8978
# Epoch 123/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.2917 - accuracy: 0.8911
# Epoch 124/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.2894 - accuracy: 0.8933
# Epoch 125/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.2881 - accuracy: 0.8967
# Epoch 126/150
# 57/57 [==============================] - 0s 5ms/step - loss: 0.2884 - accuracy: 0.8922
# Epoch 127/150
# 57/57 [==============================] - 0s 7ms/step - loss: 0.2882 - accuracy: 0.9000
# Epoch 128/150
# 57/57 [==============================] - 1s 12ms/step - loss: 0.2907 - accuracy: 0.8978
# Epoch 129/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2876 - accuracy: 0.8933
# Epoch 130/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2858 - accuracy: 0.8972
# Epoch 131/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2870 - accuracy: 0.8967
# Epoch 132/150
# 57/57 [==============================] - 0s 7ms/step - loss: 0.2849 - accuracy: 0.8967
# Epoch 133/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2841 - accuracy: 0.8994
# Epoch 134/150
# 57/57 [==============================] - 0s 7ms/step - loss: 0.2851 - accuracy: 0.8956
# Epoch 135/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2838 - accuracy: 0.9022
# Epoch 136/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.2836 - accuracy: 0.8972
# Epoch 137/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.2829 - accuracy: 0.8917
# Epoch 138/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2841 - accuracy: 0.8994
# Epoch 139/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2813 - accuracy: 0.8983
# Epoch 140/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2786 - accuracy: 0.9000
# Epoch 141/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2809 - accuracy: 0.8983
# Epoch 142/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2779 - accuracy: 0.9028
# Epoch 143/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2819 - accuracy: 0.8989
# Epoch 144/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2748 - accuracy: 0.9011
# Epoch 145/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2833 - accuracy: 0.8967
# Epoch 146/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2786 - accuracy: 0.8961
# Epoch 147/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2770 - accuracy: 0.9044
# Epoch 148/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2777 - accuracy: 0.9011
# Epoch 149/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2783 - accuracy: 0.9022
# Epoch 150/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2778 - accuracy: 0.8989
# 7/7 [==============================] - 0s 7ms/step - loss: 0.5380 - accuracy: 0.8750
# Epoch 1/150
# 57/57 [==============================] - 1s 2ms/step - loss: 3.6915 - accuracy: 0.1967
# Epoch 2/150
# 57/57 [==============================] - 0s 4ms/step - loss: 2.0005 - accuracy: 0.3428
# Epoch 3/150
# 57/57 [==============================] - 0s 2ms/step - loss: 1.4901 - accuracy: 0.4711
# Epoch 4/150
# 57/57 [==============================] - 0s 3ms/step - loss: 1.2162 - accuracy: 0.5650
# Epoch 5/150
# 57/57 [==============================] - 0s 3ms/step - loss: 1.0387 - accuracy: 0.6383
# Epoch 6/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.9231 - accuracy: 0.6711
# Epoch 7/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.8413 - accuracy: 0.7017
# Epoch 8/150
# 57/57 [==============================] - 0s 6ms/step - loss: 0.7754 - accuracy: 0.7389
# Epoch 9/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.7177 - accuracy: 0.7544
# Epoch 10/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.6618 - accuracy: 0.7811
# Epoch 11/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.6215 - accuracy: 0.7950
# Epoch 12/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.5852 - accuracy: 0.8150
# Epoch 13/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.5576 - accuracy: 0.8206
# Epoch 14/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.5351 - accuracy: 0.8300
# Epoch 15/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.5174 - accuracy: 0.8350
# Epoch 16/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.5010 - accuracy: 0.8383
# Epoch 17/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.4883 - accuracy: 0.8394
# Epoch 18/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.4789 - accuracy: 0.8417
# Epoch 19/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.4692 - accuracy: 0.8433
# Epoch 20/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.4599 - accuracy: 0.8439
# Epoch 21/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.4522 - accuracy: 0.8467
# Epoch 22/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.4449 - accuracy: 0.8528
# Epoch 23/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.4367 - accuracy: 0.8539
# Epoch 24/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.4319 - accuracy: 0.8544
# Epoch 25/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.4239 - accuracy: 0.8589
# Epoch 26/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.4171 - accuracy: 0.8606
# Epoch 27/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.4132 - accuracy: 0.8572
# Epoch 28/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.4098 - accuracy: 0.8594
# Epoch 29/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.4040 - accuracy: 0.8633
# Epoch 30/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3988 - accuracy: 0.8622
# Epoch 31/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3942 - accuracy: 0.8633
# Epoch 32/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3928 - accuracy: 0.8606
# Epoch 33/150
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3891 - accuracy: 0.8656
# Epoch 34/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3869 - accuracy: 0.8667
# Epoch 35/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3832 - accuracy: 0.8661
# Epoch 36/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3793 - accuracy: 0.8706
# Epoch 37/150
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3803 - accuracy: 0.8728
# Epoch 38/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3758 - accuracy: 0.8706
# Epoch 39/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3733 - accuracy: 0.8667
# Epoch 40/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3706 - accuracy: 0.8717
# Epoch 41/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3681 - accuracy: 0.8711
# Epoch 42/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3659 - accuracy: 0.8722
# Epoch 43/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3646 - accuracy: 0.8711
# Epoch 44/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3601 - accuracy: 0.8778
# Epoch 45/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3581 - accuracy: 0.8761
# Epoch 46/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3601 - accuracy: 0.8733
# Epoch 47/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3573 - accuracy: 0.8711
# Epoch 48/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3544 - accuracy: 0.8756
# Epoch 49/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3532 - accuracy: 0.8761
# Epoch 50/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3553 - accuracy: 0.8750
# Epoch 51/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3482 - accuracy: 0.8789
# Epoch 52/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3463 - accuracy: 0.8767
# Epoch 53/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3480 - accuracy: 0.8800
# Epoch 54/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3442 - accuracy: 0.8772
# Epoch 55/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3442 - accuracy: 0.8789
# Epoch 56/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3424 - accuracy: 0.8761
# Epoch 57/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3416 - accuracy: 0.8783
# Epoch 58/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3383 - accuracy: 0.8806
# Epoch 59/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3363 - accuracy: 0.8789
# Epoch 60/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3377 - accuracy: 0.8822
# Epoch 61/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3353 - accuracy: 0.8811
# Epoch 62/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3333 - accuracy: 0.8856
# Epoch 63/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3328 - accuracy: 0.8783
# Epoch 64/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3289 - accuracy: 0.8817
# Epoch 65/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3321 - accuracy: 0.8794
# Epoch 66/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3279 - accuracy: 0.8850
# Epoch 67/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3252 - accuracy: 0.8872
# Epoch 68/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3252 - accuracy: 0.8878
# Epoch 69/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3218 - accuracy: 0.8878
# Epoch 70/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3224 - accuracy: 0.8861
# Epoch 71/150
# 57/57 [==============================] - 1s 9ms/step - loss: 0.3213 - accuracy: 0.8867
# Epoch 72/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3174 - accuracy: 0.8878
# Epoch 73/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3176 - accuracy: 0.8872
# Epoch 74/150
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3166 - accuracy: 0.8850
# Epoch 75/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3160 - accuracy: 0.8878
# Epoch 76/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3172 - accuracy: 0.8889
# Epoch 77/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3143 - accuracy: 0.8872
# Epoch 78/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3118 - accuracy: 0.8850
# Epoch 79/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3125 - accuracy: 0.8883
# Epoch 80/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3101 - accuracy: 0.8906
# Epoch 81/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3080 - accuracy: 0.8917
# Epoch 82/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3080 - accuracy: 0.8900
# Epoch 83/150
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3071 - accuracy: 0.8894
# Epoch 84/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3070 - accuracy: 0.8922
# Epoch 85/150
# 57/57 [==============================] - 1s 9ms/step - loss: 0.3067 - accuracy: 0.8928
# Epoch 86/150
# 57/57 [==============================] - 1s 9ms/step - loss: 0.3041 - accuracy: 0.8928
# Epoch 87/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3034 - accuracy: 0.8878
# Epoch 88/150
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3018 - accuracy: 0.8950
# Epoch 89/150
# 57/57 [==============================] - 1s 13ms/step - loss: 0.3017 - accuracy: 0.8933
# Epoch 90/150
# 57/57 [==============================] - 1s 16ms/step - loss: 0.2994 - accuracy: 0.8928
# Epoch 91/150
# 57/57 [==============================] - 0s 7ms/step - loss: 0.2972 - accuracy: 0.8967
# Epoch 92/150
# 57/57 [==============================] - 0s 6ms/step - loss: 0.2955 - accuracy: 0.8978
# Epoch 93/150
# 57/57 [==============================] - 0s 6ms/step - loss: 0.2952 - accuracy: 0.8978
# Epoch 94/150
# 57/57 [==============================] - 1s 13ms/step - loss: 0.2934 - accuracy: 0.9017
# Epoch 95/150
# 57/57 [==============================] - 1s 17ms/step - loss: 0.2955 - accuracy: 0.8950
# Epoch 96/150
# 57/57 [==============================] - 1s 11ms/step - loss: 0.2955 - accuracy: 0.8961
# Epoch 97/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2952 - accuracy: 0.8950
# Epoch 98/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2910 - accuracy: 0.8944
# Epoch 99/150
# 57/57 [==============================] - 1s 15ms/step - loss: 0.2909 - accuracy: 0.8956
# Epoch 100/150
# 57/57 [==============================] - 1s 10ms/step - loss: 0.2895 - accuracy: 0.8972
# Epoch 101/150
# 57/57 [==============================] - 0s 7ms/step - loss: 0.2903 - accuracy: 0.9000
# Epoch 102/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2900 - accuracy: 0.8967
# Epoch 103/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.2888 - accuracy: 0.8967
# Epoch 104/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.2876 - accuracy: 0.8983
# Epoch 105/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.2875 - accuracy: 0.8978
# Epoch 106/150
# 57/57 [==============================] - 1s 23ms/step - loss: 0.2864 - accuracy: 0.8994
# Epoch 107/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.2854 - accuracy: 0.9000
# Epoch 108/150
# 57/57 [==============================] - 0s 5ms/step - loss: 0.2840 - accuracy: 0.8989
# Epoch 109/150
# 57/57 [==============================] - 1s 14ms/step - loss: 0.2835 - accuracy: 0.9028
# Epoch 110/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2832 - accuracy: 0.8950
# Epoch 111/150
# 57/57 [==============================] - 1s 15ms/step - loss: 0.2849 - accuracy: 0.8978
# Epoch 112/150
# 57/57 [==============================] - 0s 7ms/step - loss: 0.2803 - accuracy: 0.9006
# Epoch 113/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2797 - accuracy: 0.9011
# Epoch 114/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2805 - accuracy: 0.9017
# Epoch 115/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2775 - accuracy: 0.9006
# Epoch 116/150
# 57/57 [==============================] - 0s 6ms/step - loss: 0.2753 - accuracy: 0.9044
# Epoch 117/150
# 57/57 [==============================] - 0s 5ms/step - loss: 0.2764 - accuracy: 0.9022
# Epoch 118/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2766 - accuracy: 0.9039
# Epoch 119/150
# 57/57 [==============================] - 0s 6ms/step - loss: 0.2776 - accuracy: 0.9072
# Epoch 120/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.2744 - accuracy: 0.9006
# Epoch 121/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2743 - accuracy: 0.9028
# Epoch 122/150
# 57/57 [==============================] - 0s 8ms/step - loss: 0.2724 - accuracy: 0.9061
# Epoch 123/150
# 57/57 [==============================] - 0s 9ms/step - loss: 0.2736 - accuracy: 0.9033
# Epoch 124/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2730 - accuracy: 0.9022
# Epoch 125/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2712 - accuracy: 0.9050
# Epoch 126/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.2715 - accuracy: 0.9050
# Epoch 127/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2687 - accuracy: 0.9044
# Epoch 128/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2723 - accuracy: 0.9083
# Epoch 129/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2676 - accuracy: 0.9044
# Epoch 130/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2675 - accuracy: 0.9106
# Epoch 131/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2679 - accuracy: 0.9061
# Epoch 132/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.2656 - accuracy: 0.9078
# Epoch 133/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2648 - accuracy: 0.9067
# Epoch 134/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2642 - accuracy: 0.9078
# Epoch 135/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2670 - accuracy: 0.9072
# Epoch 136/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2641 - accuracy: 0.9111
# Epoch 137/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2619 - accuracy: 0.9067
# Epoch 138/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2641 - accuracy: 0.9078
# Epoch 139/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2612 - accuracy: 0.9128
# Epoch 140/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2618 - accuracy: 0.9072
# Epoch 141/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2612 - accuracy: 0.9061
# Epoch 142/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2575 - accuracy: 0.9150
# Epoch 143/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2563 - accuracy: 0.9133
# Epoch 144/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2578 - accuracy: 0.9111
# Epoch 145/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2591 - accuracy: 0.9072
# Epoch 146/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2561 - accuracy: 0.9083
# Epoch 147/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2548 - accuracy: 0.9111
# Epoch 148/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2563 - accuracy: 0.9156
# Epoch 149/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2553 - accuracy: 0.9089
# Epoch 150/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2561 - accuracy: 0.9089
# 7/7 [==============================] - 0s 1ms/step - loss: 0.6099 - accuracy: 0.8150
# Epoch 1/150
# 57/57 [==============================] - 2s 8ms/step - loss: 3.7048 - accuracy: 0.1544
# Epoch 2/150
# 57/57 [==============================] - 0s 5ms/step - loss: 1.9689 - accuracy: 0.3306
# Epoch 3/150
# 57/57 [==============================] - 0s 8ms/step - loss: 1.4311 - accuracy: 0.5033
# Epoch 4/150
# 57/57 [==============================] - 0s 4ms/step - loss: 1.1655 - accuracy: 0.6050
# Epoch 5/150
# 57/57 [==============================] - 0s 2ms/step - loss: 1.0101 - accuracy: 0.6700
# Epoch 6/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.9025 - accuracy: 0.7056
# Epoch 7/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.8132 - accuracy: 0.7417
# Epoch 8/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.7443 - accuracy: 0.7606
# Epoch 9/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.6900 - accuracy: 0.7772
# Epoch 10/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.6488 - accuracy: 0.7833
# Epoch 11/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.6164 - accuracy: 0.7939
# Epoch 12/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.5867 - accuracy: 0.8089
# Epoch 13/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.5657 - accuracy: 0.8117
# Epoch 14/150
# 57/57 [==============================] - 0s 9ms/step - loss: 0.5442 - accuracy: 0.8133
# Epoch 15/150
# 57/57 [==============================] - 0s 5ms/step - loss: 0.5288 - accuracy: 0.8278
# Epoch 16/150
# 57/57 [==============================] - 1s 23ms/step - loss: 0.5137 - accuracy: 0.8294
# Epoch 17/150
# 57/57 [==============================] - 0s 8ms/step - loss: 0.5040 - accuracy: 0.8328
# Epoch 18/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.4940 - accuracy: 0.8400
# Epoch 19/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.4811 - accuracy: 0.8367
# Epoch 20/150
# 57/57 [==============================] - 1s 10ms/step - loss: 0.4731 - accuracy: 0.8383
# Epoch 21/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.4635 - accuracy: 0.8439
# Epoch 22/150
# 57/57 [==============================] - 0s 6ms/step - loss: 0.4536 - accuracy: 0.8478
# Epoch 23/150
# 57/57 [==============================] - 0s 6ms/step - loss: 0.4502 - accuracy: 0.8467
# Epoch 24/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.4417 - accuracy: 0.8500
# Epoch 25/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.4354 - accuracy: 0.8528
# Epoch 26/150
# ...
# Epoch 146/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2697 - accuracy: 0.9083
# Epoch 147/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.2665 - accuracy: 0.9150
# Epoch 148/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2685 - accuracy: 0.9144
# Epoch 149/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2659 - accuracy: 0.9139
# Epoch 150/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2685 - accuracy: 0.9133
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7068 - accuracy: 0.8150
# Epoch 1/150
# 57/57 [==============================] - 1s 3ms/step - loss: 5.6587 - accuracy: 0.2422
# Epoch 2/150
# 57/57 [==============================] - 0s 4ms/step - loss: 2.5489 - accuracy: 0.3417
# Epoch 3/150
# 57/57 [==============================] - 0s 5ms/step - loss: 1.7526 - accuracy: 0.4717
# Epoch 4/150
# 57/57 [==============================] - 0s 3ms/step - loss: 1.3865 - accuracy: 0.5611
# Epoch 5/150
# 57/57 [==============================] - 0s 3ms/step - loss: 1.1581 - accuracy: 0.6283
# Epoch 6/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.9912 - accuracy: 0.6933
# Epoch 7/150
# 57/57 [==============================] - 0s 5ms/step - loss: 0.8632 - accuracy: 0.7378
# Epoch 8/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.7651 - accuracy: 0.7567
# Epoch 9/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.7002 - accuracy: 0.7811
# Epoch 10/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.6504 - accuracy: 0.7967
# Epoch 11/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.6187 - accuracy: 0.8056
# Epoch 12/150
# 57/57 [==============================] - 0s 6ms/step - loss: 0.5908 - accuracy: 0.8133
# Epoch 13/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.5716 - accuracy: 0.8144
# Epoch 14/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.5553 - accuracy: 0.8211
# Epoch 15/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.5403 - accuracy: 0.8161
# Epoch 16/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.5272 - accuracy: 0.8228
# Epoch 17/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.5174 - accuracy: 0.8211
# Epoch 18/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.5061 - accuracy: 0.8233
# Epoch 19/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.4962 - accuracy: 0.8244
# Epoch 20/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.4899 - accuracy: 0.8311
# Epoch 21/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.4791 - accuracy: 0.8339
# Epoch 22/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.4718 - accuracy: 0.8406
# Epoch 23/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.4667 - accuracy: 0.8367
# Epoch 24/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.4628 - accuracy: 0.8372
# Epoch 25/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.4562 - accuracy: 0.8444
# Epoch 26/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.4491 - accuracy: 0.8494
# Epoch 27/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.4460 - accuracy: 0.8506
# Epoch 28/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.4412 - accuracy: 0.8467
# Epoch 29/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.4371 - accuracy: 0.8517
# Epoch 30/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.4314 - accuracy: 0.8561
# Epoch 31/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.4304 - accuracy: 0.8550
# Epoch 32/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.4253 - accuracy: 0.8600
# Epoch 33/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.4230 - accuracy: 0.8561
# Epoch 34/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.4171 - accuracy: 0.8600
# Epoch 35/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.4132 - accuracy: 0.8650
# Epoch 36/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.4122 - accuracy: 0.8633
# Epoch 37/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.4092 - accuracy: 0.8622
# Epoch 38/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.4032 - accuracy: 0.8639
# Epoch 39/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.4036 - accuracy: 0.8622
# Epoch 40/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3996 - accuracy: 0.8617
# Epoch 41/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3975 - accuracy: 0.8656
# Epoch 42/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3981 - accuracy: 0.8622
# Epoch 43/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3943 - accuracy: 0.8628
# Epoch 44/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3935 - accuracy: 0.8689
# Epoch 45/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3888 - accuracy: 0.8689
# Epoch 46/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3894 - accuracy: 0.8678
# Epoch 47/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3846 - accuracy: 0.8739
# Epoch 48/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3867 - accuracy: 0.8694
# Epoch 49/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3828 - accuracy: 0.8728
# Epoch 50/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3812 - accuracy: 0.8728
# Epoch 51/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3783 - accuracy: 0.8739
# Epoch 52/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3754 - accuracy: 0.8733
# Epoch 53/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3760 - accuracy: 0.8722
# Epoch 54/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3736 - accuracy: 0.8733
# Epoch 55/150
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3711 - accuracy: 0.8739
# Epoch 56/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3712 - accuracy: 0.8722
# Epoch 57/150
# 57/57 [==============================] - 0s 8ms/step - loss: 0.3693 - accuracy: 0.8778
# Epoch 58/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3662 - accuracy: 0.8767
# Epoch 59/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3681 - accuracy: 0.8689
# Epoch 60/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3665 - accuracy: 0.8728
# Epoch 61/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3644 - accuracy: 0.8778
# Epoch 62/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3611 - accuracy: 0.8806
# Epoch 63/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3637 - accuracy: 0.8767
# Epoch 64/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3576 - accuracy: 0.8778
# Epoch 65/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3585 - accuracy: 0.8783
# Epoch 66/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3570 - accuracy: 0.8772
# Epoch 67/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3552 - accuracy: 0.8806
# Epoch 68/150
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3559 - accuracy: 0.8722
# Epoch 69/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3491 - accuracy: 0.8844
# Epoch 70/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3529 - accuracy: 0.8806
# Epoch 71/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3471 - accuracy: 0.8783
# Epoch 72/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3445 - accuracy: 0.8817
# Epoch 73/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3420 - accuracy: 0.8828
# Epoch 74/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3442 - accuracy: 0.8872
# Epoch 75/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3433 - accuracy: 0.8822
# Epoch 76/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3465 - accuracy: 0.8917
# Epoch 77/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3358 - accuracy: 0.8878
# Epoch 78/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3388 - accuracy: 0.8867
# Epoch 79/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3372 - accuracy: 0.8844
# Epoch 80/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3352 - accuracy: 0.8878
# Epoch 81/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3320 - accuracy: 0.8944
# Epoch 82/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3320 - accuracy: 0.8878
# Epoch 83/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3314 - accuracy: 0.8867
# Epoch 84/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3318 - accuracy: 0.8872
# Epoch 85/150
# 57/57 [==============================] - 0s 6ms/step - loss: 0.3288 - accuracy: 0.8878
# Epoch 86/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3281 - accuracy: 0.8861
# Epoch 87/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3270 - accuracy: 0.8894
# Epoch 88/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3273 - accuracy: 0.8911
# Epoch 89/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3256 - accuracy: 0.8928
# Epoch 90/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3236 - accuracy: 0.8933
# Epoch 91/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3245 - accuracy: 0.8922
# Epoch 92/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3201 - accuracy: 0.8944
# Epoch 93/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3225 - accuracy: 0.8922
# Epoch 94/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3212 - accuracy: 0.8956
# Epoch 95/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3200 - accuracy: 0.8944
# Epoch 96/150
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3173 - accuracy: 0.8967
# Epoch 97/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3171 - accuracy: 0.8933
# Epoch 98/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3164 - accuracy: 0.8972
# Epoch 99/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3185 - accuracy: 0.8983
# Epoch 100/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3174 - accuracy: 0.8972
# Epoch 101/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3093 - accuracy: 0.8983
# Epoch 102/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3156 - accuracy: 0.8933
# Epoch 103/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3143 - accuracy: 0.8967
# Epoch 104/150
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3143 - accuracy: 0.8933
# Epoch 105/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3093 - accuracy: 0.8928
# Epoch 106/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3107 - accuracy: 0.8961
# Epoch 107/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3106 - accuracy: 0.8956
# Epoch 108/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3073 - accuracy: 0.9028
# Epoch 109/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3063 - accuracy: 0.9028
# Epoch 110/150
# 57/57 [==============================] - 0s 7ms/step - loss: 0.3059 - accuracy: 0.9006
# Epoch 111/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3051 - accuracy: 0.9017
# Epoch 112/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3048 - accuracy: 0.9000
# Epoch 113/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3055 - accuracy: 0.8989
# Epoch 114/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3064 - accuracy: 0.8972
# Epoch 115/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3028 - accuracy: 0.9000
# Epoch 116/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3027 - accuracy: 0.9056
# Epoch 117/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3037 - accuracy: 0.9028
# Epoch 118/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3013 - accuracy: 0.9044
# Epoch 119/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3019 - accuracy: 0.8983
# Epoch 120/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2983 - accuracy: 0.9028
# Epoch 121/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2972 - accuracy: 0.9033
# Epoch 122/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2999 - accuracy: 0.8967
# Epoch 123/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2972 - accuracy: 0.9056
# Epoch 124/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2951 - accuracy: 0.9028
# Epoch 125/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2993 - accuracy: 0.9000
# Epoch 126/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2956 - accuracy: 0.9022
# Epoch 127/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.2938 - accuracy: 0.9039
# Epoch 128/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.2954 - accuracy: 0.8967
# Epoch 129/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2958 - accuracy: 0.9028
# Epoch 130/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2931 - accuracy: 0.9028
# Epoch 131/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2931 - accuracy: 0.9061
# Epoch 132/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2937 - accuracy: 0.9000
# Epoch 133/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2902 - accuracy: 0.9050
# Epoch 134/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2947 - accuracy: 0.9011
# Epoch 135/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2912 - accuracy: 0.9078
# Epoch 136/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2878 - accuracy: 0.9056
# Epoch 137/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2892 - accuracy: 0.9050
# Epoch 138/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2884 - accuracy: 0.9028
# Epoch 139/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2906 - accuracy: 0.9044
# Epoch 140/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2910 - accuracy: 0.9017
# Epoch 141/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2909 - accuracy: 0.9061
# Epoch 142/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.2877 - accuracy: 0.9061
# Epoch 143/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2870 - accuracy: 0.9083
# Epoch 144/150
# 57/57 [==============================] - 0s 4ms/step - loss: 0.2886 - accuracy: 0.9022
# Epoch 145/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2846 - accuracy: 0.9089
# Epoch 146/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2847 - accuracy: 0.9061
# Epoch 147/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2830 - accuracy: 0.9128
# Epoch 148/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2827 - accuracy: 0.9083
# Epoch 149/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2863 - accuracy: 0.9011
# Epoch 150/150
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2847 - accuracy: 0.9089
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6196 - accuracy: 0.8300
# CPU times: user 3min 38s, sys: 33.2 s, total: 4min 11s
# Wall time: 7min 4s
# [0.800000011920929,
#  0.875,
#  0.8149999976158142,
#  0.824999988079071,
#  0.7799999713897705,
#  0.7749999761581421,
#  0.7799999713897705,
#  0.7549999952316284,
#  0.8149999976158142,
#  0.8299999833106995]

# %% [markdown]
# ### Performance of the Cross-Validated Network
#
# Print the average accuracy of these 10 folds and the standard deviation of these 10 accuracy values.

# %%
accuracy = results

print(f'New mean accuracy: {np.mean(accuracy)*100:.2f}% (±{np.std(accuracy)*100:.2f})')
# Out:
# New mean accuracy: 80.50% (±3.29)

# %% [markdown]
# ### Remarks About the Computational Time
#
# - 🤯 You probably encountered one of the main drawbacks of using proper cross-validation for a Neural Network: **it takes a lot of time**! Therefore, for the rest of the Deep-Learning module, we will do **only one fold**
# - 👮🏻‍♀️ Remember that this is not entirely correct and, for real-life applications and problems, you are encouraged to use a proper cross-validation technique
# - 💼 In general, people split only once, as you did. Once they get to the end of their optimization, they launch a real cross-validation run at 6 PM, go home and get the final results on the next day

# %% [markdown]
# ### Holdout Method
#
# For the rest of the exercise (and of the Deep Learning module), split the dataset into a training set and a testing set with a 70/30% training-to-test data ratio.
#
# Make sure to also scale the data after splitting!

# %%
# YOUR CODE HERE
X_train,X_test,y_train,y_test = train_test_split(X,y_cat,train_size=70,test_size=30)

# %%
X_test.shape
# Out:
# (30, 10)

# %%
# Scale the data
SScaler = StandardScaler()
SScaler.fit(X_train)

X_train_scaled = SScaler.transform(X_train)
X_test_scaled = SScaler.transform(X_test)

# %% [markdown]
# ## (2) How to Prevent a Neural Network from Overfitting?

# %% [markdown]
# ### (2.1) Early Stopping
#
# 🚦 **Stop the learning process before overfitting**

# %% [markdown]
# #### Illustrating How a Neural Network Easily Overfits
#
# First things first, let's show that if we train the model for too long (= for too many epochs) it will overfit the training data and will not be good at predicting the testing data.
#
# **How can we do it without using the testing data, which is strictly forbidden?**
#
# You can use a fraction of the <font color=blue>training set</font> as a <font color=green>validation set</font>.
#
# <img src="https://wagon-public-datasets.s3.amazonaws.com/data-science-images/lectures/deep-learning/02/validation_set.png" width=450>
#
# With Keras, you don't have to re-use the `train_test_split` method from Scikit-Learn. Instead, you have two options:
#
# - `validation_split = 0.2` (for example)
#     - The model will take the last 20% of the observations in the training set and use this group as the validation holdout set
#     - If you want a random `train_val_split` within the training set, you can also add the argument `shuffle = True` in `model.fit()`
# - `validation_data = (X_val, y_val)` if you have access to a dataset that you want to use as the validation holdout set.
#
# 👉 Let's go with the first option and set `epochs = 500`.
#
# 👉 Store the performances of the model in a `history` variable.

# %%
# %%time
    history = model.fit(
            X_train, y_train,
            validation_split=0.2,
            batch_size=16,
            epochs=500      
    )
# Out:
# Epoch 1/500
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.3539 - val_accuracy: 0.7857
# Epoch 2/500
# 4/4 [==============================] - 1s 221ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.3541 - val_accuracy: 0.7857
# Epoch 3/500
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.3541 - val_accuracy: 0.7857
# Epoch 4/500
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.3543 - val_accuracy: 0.7857
# Epoch 5/500
# 4/4 [==============================] - 0s 141ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.3545 - val_accuracy: 0.7857
# Epoch 6/500
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.3547 - val_accuracy: 0.7857
# Epoch 7/500
# 4/4 [==============================] - 0s 153ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.3547 - val_accuracy: 0.7857
# Epoch 8/500
# 4/4 [==============================] - 0s 57ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.3549 - val_accuracy: 0.7857
# Epoch 9/500
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.3551 - val_accuracy: 0.7857
# Epoch 10/500
# 4/4 [==============================] - 1s 261ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.3554 - val_accuracy: 0.7857
# Epoch 11/500
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.3556 - val_accuracy: 0.7857
# Epoch 12/500
# 4/4 [==============================] - 1s 225ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.3556 - val_accuracy: 0.7857
# Epoch 13/500
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.3557 - val_accuracy: 0.7857
# Epoch 14/500
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.3559 - val_accuracy: 0.7857
# Epoch 15/500
# 4/4 [==============================] - 0s 82ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.3562 - val_accuracy: 0.7857
# Epoch 16/500
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.3564 - val_accuracy: 0.7857
# Epoch 17/500
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.3565 - val_accuracy: 0.7857
# Epoch 18/500
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.3566 - val_accuracy: 0.7857
# Epoch 19/500
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.3567 - val_accuracy: 0.7857
# Epoch 20/500
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.3569 - val_accuracy: 0.7857
# Epoch 21/500
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.3572 - val_accuracy: 0.7857
# Epoch 22/500
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.3577 - val_accuracy: 0.7857
# Epoch 23/500
# 4/4 [==============================] - 0s 71ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.3580 - val_accuracy: 0.7857
# Epoch 24/500
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.3583 - val_accuracy: 0.7857
# Epoch 25/500
# 4/4 [==============================] - 0s 65ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.3585 - val_accuracy: 0.7857
# Epoch 26/500
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.3587 - val_accuracy: 0.7857
# Epoch 27/500
# 4/4 [==============================] - 1s 161ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.3589 - val_accuracy: 0.7857
# Epoch 28/500
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.3589 - val_accuracy: 0.7857
# Epoch 29/500
# 4/4 [==============================] - 0s 126ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.3593 - val_accuracy: 0.7857
# Epoch 30/500
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.3595 - val_accuracy: 0.7857
# Epoch 31/500
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.3600 - val_accuracy: 0.7857
# Epoch 32/500
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.3602 - val_accuracy: 0.7857
# Epoch 33/500
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.3602 - val_accuracy: 0.7857
# Epoch 34/500
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.3607 - val_accuracy: 0.7857
# Epoch 35/500
# 4/4 [==============================] - 0s 68ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.3611 - val_accuracy: 0.7857
# Epoch 36/500
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.3613 - val_accuracy: 0.7857
# Epoch 37/500
# 4/4 [==============================] - 0s 64ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.3614 - val_accuracy: 0.7857
# Epoch 38/500
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.3616 - val_accuracy: 0.7857
# Epoch 39/500
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.3616 - val_accuracy: 0.7857
# Epoch 40/500
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.3618 - val_accuracy: 0.7857
# Epoch 41/500
# 4/4 [==============================] - 0s 60ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.3620 - val_accuracy: 0.7857
# Epoch 42/500
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.3625 - val_accuracy: 0.7857
# Epoch 43/500
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.3629 - val_accuracy: 0.7857
# Epoch 44/500
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.3631 - val_accuracy: 0.7857
# Epoch 45/500
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.3633 - val_accuracy: 0.7857
# Epoch 46/500
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.3635 - val_accuracy: 0.7857
# Epoch 47/500
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.3638 - val_accuracy: 0.7857
# Epoch 48/500
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.3639 - val_accuracy: 0.7857
# Epoch 49/500
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.3643 - val_accuracy: 0.7857
# Epoch 50/500
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.3647 - val_accuracy: 0.7857
# Epoch 51/500
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.3651 - val_accuracy: 0.7857
# Epoch 52/500
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.3658 - val_accuracy: 0.7857
# Epoch 53/500
# 4/4 [==============================] - 0s 102ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.3660 - val_accuracy: 0.7857
# Epoch 54/500
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.3661 - val_accuracy: 0.7857
# Epoch 55/500
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.3663 - val_accuracy: 0.7857
# Epoch 56/500
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.3664 - val_accuracy: 0.7857
# Epoch 57/500
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.3666 - val_accuracy: 0.7857
# Epoch 58/500
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.3668 - val_accuracy: 0.7857
# Epoch 59/500
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.3671 - val_accuracy: 0.7857
# Epoch 60/500
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.3673 - val_accuracy: 0.7857
# Epoch 61/500
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.3676 - val_accuracy: 0.7857
# Epoch 62/500
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.3678 - val_accuracy: 0.7857
# Epoch 63/500
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.3680 - val_accuracy: 0.7857
# Epoch 64/500
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.3684 - val_accuracy: 0.7857
# Epoch 65/500
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.3687 - val_accuracy: 0.7857
# Epoch 66/500
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.3688 - val_accuracy: 0.7857
# Epoch 67/500
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.3690 - val_accuracy: 0.7857
# Epoch 68/500
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.3690 - val_accuracy: 0.7857
# Epoch 69/500
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.3691 - val_accuracy: 0.7857
# Epoch 70/500
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.3692 - val_accuracy: 0.7857
# Epoch 71/500
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.3696 - val_accuracy: 0.7857
# Epoch 72/500
# 4/4 [==============================] - 1s 195ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.3698 - val_accuracy: 0.7857
# Epoch 73/500
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.3701 - val_accuracy: 0.7857
# Epoch 74/500
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.3706 - val_accuracy: 0.7857
# Epoch 75/500
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.3709 - val_accuracy: 0.7857
# Epoch 76/500
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.3710 - val_accuracy: 0.7857
# Epoch 77/500
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.3710 - val_accuracy: 0.7857
# Epoch 78/500
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.3712 - val_accuracy: 0.7857
# Epoch 79/500
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.3713 - val_accuracy: 0.7857
# Epoch 80/500
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.3714 - val_accuracy: 0.7857
# Epoch 81/500
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.3714 - val_accuracy: 0.7857
# Epoch 82/500
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.3719 - val_accuracy: 0.7857
# Epoch 83/500
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.3723 - val_accuracy: 0.7857
# Epoch 84/500
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.3727 - val_accuracy: 0.7857
# Epoch 85/500
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.3730 - val_accuracy: 0.7857
# Epoch 86/500
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.3731 - val_accuracy: 0.7857
# Epoch 87/500
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.3732 - val_accuracy: 0.7857
# Epoch 88/500
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.3734 - val_accuracy: 0.7857
# Epoch 89/500
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.3736 - val_accuracy: 0.7857
# Epoch 90/500
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.3739 - val_accuracy: 0.7857
# Epoch 91/500
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.3741 - val_accuracy: 0.7857
# Epoch 92/500
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.3742 - val_accuracy: 0.7857
# Epoch 93/500
# 4/4 [==============================] - 0s 102ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.3743 - val_accuracy: 0.7857
# Epoch 94/500
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.3744 - val_accuracy: 0.7857
# Epoch 95/500
# 4/4 [==============================] - 0s 51ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.3746 - val_accuracy: 0.7857
# Epoch 96/500
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.3747 - val_accuracy: 0.7857
# Epoch 97/500
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.3750 - val_accuracy: 0.7857
# Epoch 98/500
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.3751 - val_accuracy: 0.7857
# Epoch 99/500
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.3753 - val_accuracy: 0.7857
# Epoch 100/500
# 4/4 [==============================] - 0s 43ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.3755 - val_accuracy: 0.7857
# Epoch 101/500
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.3757 - val_accuracy: 0.7857
# Epoch 102/500
# 4/4 [==============================] - 0s 43ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.3758 - val_accuracy: 0.7857
# Epoch 103/500
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.3759 - val_accuracy: 0.7857
# Epoch 104/500
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.3761 - val_accuracy: 0.7857
# Epoch 105/500
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.3762 - val_accuracy: 0.7857
# Epoch 106/500
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.3764 - val_accuracy: 0.7857
# Epoch 107/500
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.3764 - val_accuracy: 0.7857
# Epoch 108/500
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.3764 - val_accuracy: 0.7857
# Epoch 109/500
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.3768 - val_accuracy: 0.7857
# Epoch 110/500
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.3771 - val_accuracy: 0.7857
# Epoch 111/500
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.3773 - val_accuracy: 0.7857
# Epoch 112/500
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.3775 - val_accuracy: 0.7857
# Epoch 113/500
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.3777 - val_accuracy: 0.7857
# Epoch 114/500
# 4/4 [==============================] - 1s 166ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.3777 - val_accuracy: 0.7857
# Epoch 115/500
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.3779 - val_accuracy: 0.7857
# Epoch 116/500
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.3780 - val_accuracy: 0.7857
# Epoch 117/500
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.3781 - val_accuracy: 0.7857
# Epoch 118/500
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.3783 - val_accuracy: 0.7857
# Epoch 119/500
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.3784 - val_accuracy: 0.7857
# Epoch 120/500
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.3787 - val_accuracy: 0.7857
# Epoch 121/500
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.3790 - val_accuracy: 0.7857
# Epoch 122/500
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.3793 - val_accuracy: 0.7857
# Epoch 123/500
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.3794 - val_accuracy: 0.7857
# Epoch 124/500
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.3795 - val_accuracy: 0.7857
# Epoch 125/500
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.3797 - val_accuracy: 0.7857
# Epoch 126/500
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.3801 - val_accuracy: 0.7857
# Epoch 127/500
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.3802 - val_accuracy: 0.7857
# Epoch 128/500
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.3803 - val_accuracy: 0.7857
# Epoch 129/500
# 4/4 [==============================] - 1s 201ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.3805 - val_accuracy: 0.7857
# Epoch 130/500
# 4/4 [==============================] - 0s 50ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.3806 - val_accuracy: 0.7857
# Epoch 131/500
# 4/4 [==============================] - 0s 59ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.3807 - val_accuracy: 0.7857
# Epoch 132/500
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.3810 - val_accuracy: 0.7857
# Epoch 133/500
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.3813 - val_accuracy: 0.7857
# Epoch 134/500
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.3816 - val_accuracy: 0.7857
# Epoch 135/500
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.3821 - val_accuracy: 0.7857
# Epoch 136/500
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.3823 - val_accuracy: 0.7857
# Epoch 137/500
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.3825 - val_accuracy: 0.7857
# Epoch 138/500
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.3826 - val_accuracy: 0.7857
# Epoch 139/500
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.3829 - val_accuracy: 0.7857
# Epoch 140/500
# 4/4 [==============================] - 0s 50ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.3832 - val_accuracy: 0.7857
# Epoch 141/500
# 4/4 [==============================] - 0s 102ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.3836 - val_accuracy: 0.7857
# Epoch 142/500
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.3838 - val_accuracy: 0.7857
# Epoch 143/500
# 4/4 [==============================] - 0s 89ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.3840 - val_accuracy: 0.7857
# Epoch 144/500
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.3842 - val_accuracy: 0.7857
# Epoch 145/500
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.3847 - val_accuracy: 0.7857
# Epoch 146/500
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.3851 - val_accuracy: 0.7857
# Epoch 147/500
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.3854 - val_accuracy: 0.7857
# Epoch 148/500
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3857 - val_accuracy: 0.7857
# Epoch 149/500
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3862 - val_accuracy: 0.7857
# Epoch 150/500
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3864 - val_accuracy: 0.7857
# Epoch 151/500
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3869 - val_accuracy: 0.7857
# Epoch 152/500
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3873 - val_accuracy: 0.7857
# Epoch 153/500
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3876 - val_accuracy: 0.7857
# Epoch 154/500
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3880 - val_accuracy: 0.7857
# Epoch 155/500
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3882 - val_accuracy: 0.7857
# Epoch 156/500
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3883 - val_accuracy: 0.7857
# Epoch 157/500
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3886 - val_accuracy: 0.7857
# Epoch 158/500
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3888 - val_accuracy: 0.7857
# Epoch 159/500
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3890 - val_accuracy: 0.7857
# Epoch 160/500
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3892 - val_accuracy: 0.7857
# Epoch 161/500
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3894 - val_accuracy: 0.7857
# Epoch 162/500
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3897 - val_accuracy: 0.7857
# Epoch 163/500
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3898 - val_accuracy: 0.7857
# Epoch 164/500
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3900 - val_accuracy: 0.7857
# Epoch 165/500
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3902 - val_accuracy: 0.7857
# Epoch 166/500
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3904 - val_accuracy: 0.7857
# Epoch 167/500
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3908 - val_accuracy: 0.7857
# Epoch 168/500
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3911 - val_accuracy: 0.7857
# Epoch 169/500
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3913 - val_accuracy: 0.7857
# Epoch 170/500
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3915 - val_accuracy: 0.7857
# Epoch 171/500
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3917 - val_accuracy: 0.7857
# Epoch 172/500
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3920 - val_accuracy: 0.7857
# Epoch 173/500
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3922 - val_accuracy: 0.7857
# Epoch 174/500
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3925 - val_accuracy: 0.7857
# Epoch 175/500
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3925 - val_accuracy: 0.7857
# Epoch 176/500
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3927 - val_accuracy: 0.7857
# Epoch 177/500
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3929 - val_accuracy: 0.7857
# Epoch 178/500
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3929 - val_accuracy: 0.7857
# Epoch 179/500
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3932 - val_accuracy: 0.7857
# Epoch 180/500
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3932 - val_accuracy: 0.7857
# Epoch 181/500
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3934 - val_accuracy: 0.7857
# Epoch 182/500
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3936 - val_accuracy: 0.7857
# Epoch 183/500
# 4/4 [==============================] - 0s 77ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3938 - val_accuracy: 0.7857
# Epoch 184/500
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3940 - val_accuracy: 0.7857
# Epoch 185/500
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3945 - val_accuracy: 0.7857
# Epoch 186/500
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3950 - val_accuracy: 0.7857
# Epoch 187/500
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3956 - val_accuracy: 0.7857
# Epoch 188/500
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3959 - val_accuracy: 0.7857
# Epoch 189/500
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3961 - val_accuracy: 0.7857
# Epoch 190/500
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3965 - val_accuracy: 0.7857
# Epoch 191/500
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3967 - val_accuracy: 0.7857
# Epoch 192/500
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3969 - val_accuracy: 0.7857
# Epoch 193/500
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3972 - val_accuracy: 0.7857
# Epoch 194/500
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3974 - val_accuracy: 0.7857
# Epoch 195/500
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3975 - val_accuracy: 0.7857
# Epoch 196/500
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3978 - val_accuracy: 0.7857
# Epoch 197/500
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3981 - val_accuracy: 0.7857
# Epoch 198/500
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3983 - val_accuracy: 0.7857
# Epoch 199/500
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3985 - val_accuracy: 0.7857
# Epoch 200/500
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3987 - val_accuracy: 0.7857
# Epoch 201/500
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3989 - val_accuracy: 0.7857
# Epoch 202/500
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3990 - val_accuracy: 0.7857
# Epoch 203/500
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3991 - val_accuracy: 0.7857
# Epoch 204/500
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3995 - val_accuracy: 0.7857
# Epoch 205/500
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3997 - val_accuracy: 0.7857
# Epoch 206/500
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3998 - val_accuracy: 0.7857
# Epoch 207/500
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3998 - val_accuracy: 0.7857
# Epoch 208/500
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.4001 - val_accuracy: 0.7857
# Epoch 209/500
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.4002 - val_accuracy: 0.7857
# Epoch 210/500
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4004 - val_accuracy: 0.7857
# Epoch 211/500
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4006 - val_accuracy: 0.7857
# Epoch 212/500
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4008 - val_accuracy: 0.7857
# Epoch 213/500
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4008 - val_accuracy: 0.7857
# Epoch 214/500
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4008 - val_accuracy: 0.7857
# Epoch 215/500
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4011 - val_accuracy: 0.7857
# Epoch 216/500
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4013 - val_accuracy: 0.7857
# Epoch 217/500
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4015 - val_accuracy: 0.7857
# Epoch 218/500
# 4/4 [==============================] - 0s 103ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4018 - val_accuracy: 0.7857
# Epoch 219/500
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4021 - val_accuracy: 0.7857
# Epoch 220/500
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4024 - val_accuracy: 0.7857
# Epoch 221/500
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4026 - val_accuracy: 0.7857
# Epoch 222/500
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4028 - val_accuracy: 0.7857
# Epoch 223/500
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4027 - val_accuracy: 0.7857
# Epoch 224/500
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4028 - val_accuracy: 0.7857
# Epoch 225/500
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4033 - val_accuracy: 0.7857
# Epoch 226/500
# 4/4 [==============================] - 0s 43ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4036 - val_accuracy: 0.7857
# Epoch 227/500
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4039 - val_accuracy: 0.7857
# Epoch 228/500
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4041 - val_accuracy: 0.7857
# Epoch 229/500
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4042 - val_accuracy: 0.7857
# Epoch 230/500
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4046 - val_accuracy: 0.7857
# Epoch 231/500
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4049 - val_accuracy: 0.7857
# Epoch 232/500
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4051 - val_accuracy: 0.7857
# Epoch 233/500
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4053 - val_accuracy: 0.7857
# Epoch 234/500
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4055 - val_accuracy: 0.7857
# Epoch 235/500
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4057 - val_accuracy: 0.7857
# Epoch 236/500
# 4/4 [==============================] - 1s 285ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4059 - val_accuracy: 0.7857
# Epoch 237/500
# 4/4 [==============================] - 1s 196ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4062 - val_accuracy: 0.7857
# Epoch 238/500
# 4/4 [==============================] - 0s 107ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4062 - val_accuracy: 0.7857
# Epoch 239/500
# 4/4 [==============================] - 1s 198ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4062 - val_accuracy: 0.7857
# Epoch 240/500
# 4/4 [==============================] - 1s 153ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4063 - val_accuracy: 0.7857
# Epoch 241/500
# 4/4 [==============================] - 0s 49ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4063 - val_accuracy: 0.7857
# Epoch 242/500
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4064 - val_accuracy: 0.7857
# Epoch 243/500
# 4/4 [==============================] - 0s 147ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4066 - val_accuracy: 0.7857
# Epoch 244/500
# 4/4 [==============================] - 0s 103ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4067 - val_accuracy: 0.7857
# Epoch 245/500
# 4/4 [==============================] - 0s 90ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4068 - val_accuracy: 0.7857
# Epoch 246/500
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.4071 - val_accuracy: 0.7857
# Epoch 247/500
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.4075 - val_accuracy: 0.7857
# Epoch 248/500
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.4077 - val_accuracy: 0.7857
# Epoch 249/500
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.4080 - val_accuracy: 0.7857
# Epoch 250/500
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.4083 - val_accuracy: 0.7857
# Epoch 251/500
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.4090 - val_accuracy: 0.7857
# Epoch 252/500
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.4093 - val_accuracy: 0.7857
# Epoch 253/500
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.4095 - val_accuracy: 0.7857
# Epoch 254/500
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.4097 - val_accuracy: 0.7857
# Epoch 255/500
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.4099 - val_accuracy: 0.7857
# Epoch 256/500
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.4103 - val_accuracy: 0.7857
# Epoch 257/500
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.4105 - val_accuracy: 0.7857
# Epoch 258/500
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.4109 - val_accuracy: 0.7857
# Epoch 259/500
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.4111 - val_accuracy: 0.7857
# Epoch 260/500
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.4116 - val_accuracy: 0.7857
# Epoch 261/500
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.4120 - val_accuracy: 0.7857
# Epoch 262/500
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.4123 - val_accuracy: 0.7857
# Epoch 263/500
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.4126 - val_accuracy: 0.7857
# Epoch 264/500
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.4131 - val_accuracy: 0.7857
# Epoch 265/500
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.4134 - val_accuracy: 0.7857
# Epoch 266/500
# 4/4 [==============================] - 0s 22ms/step - loss: 9.9685e-04 - accuracy: 1.0000 - val_loss: 0.4135 - val_accuracy: 0.7857
# Epoch 267/500
# 4/4 [==============================] - 0s 30ms/step - loss: 9.9464e-04 - accuracy: 1.0000 - val_loss: 0.4137 - val_accuracy: 0.7857
# Epoch 268/500
# 4/4 [==============================] - 0s 63ms/step - loss: 9.9207e-04 - accuracy: 1.0000 - val_loss: 0.4140 - val_accuracy: 0.7857
# Epoch 269/500
# 4/4 [==============================] - 0s 41ms/step - loss: 9.8944e-04 - accuracy: 1.0000 - val_loss: 0.4141 - val_accuracy: 0.7857
# Epoch 270/500
# 4/4 [==============================] - 0s 48ms/step - loss: 9.8699e-04 - accuracy: 1.0000 - val_loss: 0.4144 - val_accuracy: 0.7857
# Epoch 271/500
# 4/4 [==============================] - 0s 17ms/step - loss: 9.8504e-04 - accuracy: 1.0000 - val_loss: 0.4146 - val_accuracy: 0.7857
# Epoch 272/500
# 4/4 [==============================] - 0s 16ms/step - loss: 9.8231e-04 - accuracy: 1.0000 - val_loss: 0.4147 - val_accuracy: 0.7857
# Epoch 273/500
# 4/4 [==============================] - 0s 25ms/step - loss: 9.8018e-04 - accuracy: 1.0000 - val_loss: 0.4148 - val_accuracy: 0
500
# 4/4 [==============================] - 0s 17ms/step - loss: 5.6320e-04 - accuracy: 1.0000 - val_loss: 0.4683 - val_accuracy: 0.7857
# CPU times: user 27 s, sys: 3.14 s, total: 30.1 s
# Wall time: 1min

# %% [markdown]
# #### Your Neural Network's Performance
#
# Evaluate the model on the testing set and print the accuracy.

# %%
# YOUR CODE HERE
loss, accuracy = model.evaluate(X_test, y_test)

# Print the accuracy
print("Accuracy on testing set: {:.2f}%".format(accuracy * 100))
# Out:
# 1/1 [==============================] - 0s 34ms/step - loss: 0.7091 - accuracy: 0.8000
# Accuracy on testing set: 80.00%

# %% [markdown]
# #### Learnings About Number of Epochs
#
# Plot the history of the model with the `plot_loss_accuracy()` function that we coded for you.
#
# What do you observe?

# %%
def plot_loss_accuracy(history, title=None):
    fig, ax = plt.subplots(1,2, figsize=(20,7))

    # --- LOSS --- 

    ax[0].plot(history.history['loss'])
    ax[0].plot(history.history['val_loss'])

    ax[0].set_title('Model loss')
    ax[0].set_ylabel('Loss')
    ax[0].set_xlabel('Epoch')

    ax[0].set_ylim((0,3))

    ax[0].legend(['Train', 'Test'], loc='best')

    ax[0].grid(axis="x",linewidth=0.5)
    ax[0].grid(axis="y",linewidth=0.5)

    # --- ACCURACY

    ax[1].plot(history.history['accuracy'])
    ax[1].plot(history.history['val_accuracy'])

    ax[1].set_title('Model Accuracy')
    ax[1].set_ylabel('Accuracy')
    ax[1].set_xlabel('Epoch')

    ax[1].legend(['Train', 'Test'], loc='best')

    ax[1].set_ylim((0,1))

    ax[1].grid(axis="x",linewidth=0.5)
    ax[1].grid(axis="y",linewidth=0.5)

    if title:
        fig.suptitle(title)

# %%
# YOUR CODE HERE
plot_loss_accuracy(history)

# %% [markdown]
# 👩🏻‍🏫 We clearly see that **the number of epochs we choose has a strong influence on the final results**:
#
# **INSUFFICIENT NUMBER OF EPOCHS $\implies$ UNDERFITTING**:
# - The algorithm is not optimal as its Loss Function has **not converged yet**
# - It hasn't learned enough from the training data
#
# **TOO MANY EPOCHS** $\implies$ **OVERFITTING**:
# - Our Neural Network has **learned too much** from the training data, including its noisy information
# - the algorithm **does not generalize well** on test data
#
# 🚦 Basically, what we want to do is stop the algorithm **when the test loss is minimal** (or when the testing metrics are maximal)

# %% [markdown]
# #### Early Stopping
#
# 🧑🏻‍🏫 Let's introduce the **Early Stopping** criterion.
#
# The Early Stopping criterion is a way to **automatically stop the training of the algorithm** before reaching the number of epochs that was originally set.
#
# 🕵🏻‍♂️ **How does it work?**
#
# The model will pay attention to the **<font color=green>loss of the validation set</font>**. If <font color=green>it</font> starts increasing again 📈 while the <font color=blue>loss of the training set</font> keeps decreasing 📉, it is a good sign that the model is overfitting and the training should be stopped!
#
#
# <img src="validation_set.png" alt="Validation set" width=450/>

# %% [markdown]
# ##### Observing the Early Stopping Criterion
#
# Run the following code and plot the history.

# %%
# %%time

es = EarlyStopping()

model = initialize_model()

# Fit the model on the train data
history = model.fit(
    X_train_scaled,
    y_train,
    validation_split = 0.3,
    epochs = 500,
    batch_size = 16, 
    verbose = 1, 
    callbacks = [es] # This will call the Early Stopping Criterion for each epoch
)
# Out:
# Epoch 1/500
# 4/4 [==============================] - 3s 184ms/step - loss: 2.2473 - accuracy: 0.1429 - val_loss: 2.1350 - val_accuracy: 0.0476
# Epoch 2/500
# 4/4 [==============================] - 0s 38ms/step - loss: 2.2163 - accuracy: 0.1633 - val_loss: 2.1253 - val_accuracy: 0.0476
# CPU times: user 1.49 s, sys: 65.4 ms, total: 1.56 s
# Wall time: 3.44 s

# %% [markdown]
# ##### Evaluate the ES Model
#
# _(also look at the historical losses)_

# %%
# YOUR CODE HERE
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plot training and validation loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %% [markdown]
# ❗ **The problem with strict Early Stopping** ❗
#
# The problem with this type of approach is that as soon as the loss of the validation set increases, the model stops. However, as a Neural Network's convergence is stochastic, the loss may slightly increase before decreasing again.
#
# ✅ The `EarlyStopping` criterion has a `patience` keyword that defines how many **consecutive epochs without any loss decrease** are allowed in the validation set before we stop the training procedure.
#
# Use the `EarlyStopping` criterion with a patience term of 30 epochs, plot the results, and print the accuracy on the testing set

# %%
# %%time

es = EarlyStopping(patience=30)

model = initialize_model()

# Fit the model on the train data
history = model.fit(
    X_train_scaled,
    y_train,
    validation_split = 0.3,
    epochs = 500,
    batch_size = 16, 
    verbose = 1, 
    callbacks = [es] # This will call the Early Stopping Criterion for each epoch
)
# Out:
# Epoch 1/500
# 4/4 [==============================] -
# 4/4 [==============================] - 0s 36ms/step - loss: 1.3156 - accuracy: 0.7143 - val_loss: 1.7561 - val_accuracy: 0.4762
# Epoch 54/500
# 4/4 [==============================] - 0s 43ms/step - loss: 1.3007 - accuracy: 0.7143 - val_loss: 1.7473 - val_accuracy: 0.4762
# Epoch 55/500
# 4/4 [==============================] - 0s 36ms/step - loss: 1.2850 - accuracy: 0.7347 - val_loss: 1.7367 - val_accuracy: 0.5238
# Epoch 56/500
# 4/4 [==============================] - 0s 31ms/step - loss: 1.2703 - accuracy: 0.7551 - val_loss: 1.7245 - val_accuracy: 0.5238
# Epoch 57/500
# 4/4 [==============================] - 0s 34ms/step - loss: 1.2543 - accuracy: 0.7755 - val_loss: 1.7087 - val_accuracy: 0.5238
# Epoch 58/500
# 4/4 [==============================] - 0s 86ms/step - loss: 1.2394 - accuracy: 0.7755 - val_loss: 1.6969 - val_accuracy: 0.5238
# Epoch 59/500
# 4/4 [==============================] - 0s 22ms/step - loss: 1.2245 - accuracy: 0.7755 - val_loss: 1.6861 - val_accuracy: 0.5238
# Epoch 60/500
# 4/4 [==============================] - 0s 25ms/step - loss: 1.2092 - accuracy: 0.7755 - val_loss: 1.6789 - val_accuracy: 0.5238
# Epoch 61/500
# 4/4 [==============================] - 0s 34ms/step - loss: 1.1940 - accuracy: 0.7959 - val_loss: 1.6730 - val_accuracy: 0.5238
# Epoch 62/500
# 4/4 [==============================] - 0s 21ms/step - loss: 1.1789 - accuracy: 0.7959 - val_loss: 1.6671 - val_accuracy: 0.5238
# Epoch 63/500
# 4/4 [==============================] - 0s 32ms/step - loss: 1.1639 - accuracy: 0.7959 - val_loss: 1.6606 - val_accuracy: 0.5238
# Epoch 64/500
# 4/4 [==============================] - 0s 28ms/step - loss: 1.1478 - accuracy: 0.7959 - val_loss: 1.6563 - val_accuracy: 0.5238
# Epoch 65/500
# 4/4 [==============================] - 0s 17ms/step - loss: 1.1333 - accuracy: 0.7959 - val_loss: 1.6536 - val_accuracy: 0.5238
# Epoch 66/500
# 4/4 [==============================] - 0s 18ms/step - loss: 1.1172 - accuracy: 0.7959 - val_loss: 1.6514 - val_accuracy: 0.5238
# Epoch 67/500
# 4/4 [==============================] - 0s 21ms/step - loss: 1.1011 - accuracy: 0.7959 - val_loss: 1.6490 - val_accuracy: 0.5238
# Epoch 68/500
# 4/4 [==============================] - 0s 22ms/step - loss: 1.0850 - accuracy: 0.7959 - val_loss: 1.6464 - val_accuracy: 0.5238
# Epoch 69/500
# 4/4 [==============================] - 0s 23ms/step - loss: 1.0682 - accuracy: 0.7959 - val_loss: 1.6411 - val_accuracy: 0.5238
# Epoch 70/500
# 4/4 [==============================] - 0s 14ms/step - loss: 1.0533 - accuracy: 0.7959 - val_loss: 1.6276 - val_accuracy: 0.5238
# Epoch 71/500
# 4/4 [==============================] - 0s 16ms/step - loss: 1.0398 - accuracy: 0.7959 - val_loss: 1.6151 - val_accuracy: 0.5238
# Epoch 72/500
# 4/4 [==============================] - 0s 27ms/step - loss: 1.0256 - accuracy: 0.7959 - val_loss: 1.6075 - val_accuracy: 0.5238
# Epoch 73/500
# 4/4 [==============================] - 0s 20ms/step - loss: 1.0115 - accuracy: 0.8163 - val_loss: 1.6053 - val_accuracy: 0.5238
# Epoch 74/500
# 4/4 [==============================] - 0s 18ms/step - loss: 0.9985 - accuracy: 0.8163 - val_loss: 1.6055 - val_accuracy: 0.5238
# Epoch 75/500
# 4/4 [==============================] - 0s 24ms/step - loss: 0.9853 - accuracy: 0.7959 - val_loss: 1.6036 - val_accuracy: 0.5238
# Epoch 76/500
# 4/4 [==============================] - 0s 17ms/step - loss: 0.9726 - accuracy: 0.7959 - val_loss: 1.6005 - val_accuracy: 0.5238
# Epoch 77/500
# 4/4 [==============================] - 0s 19ms/step - loss: 0.9595 - accuracy: 0.7959 - val_loss: 1.6001 - val_accuracy: 0.5238
# Epoch 78/500
# 4/4 [==============================] - 0s 19ms/step - loss: 0.9474 - accuracy: 0.7959 - val_loss: 1.5958 - val_accuracy: 0.5238
# Epoch 79/500
# 4/4 [==============================] - 0s 21ms/step - loss: 0.9342 - accuracy: 0.7959 - val_loss: 1.5891 - val_accuracy: 0.5238
# Epoch 80/500
# 4/4 [==============================] - 0s 17ms/step - loss: 0.9220 - accuracy: 0.8367 - val_loss: 1.5815 - val_accuracy: 0.5238
# Epoch 81/500
# 4/4 [==============================] - 1s 181ms/step - loss: 0.9096 - accuracy: 0.8367 - val_loss: 1.5759 - val_accuracy: 0.5238
# Epoch 82/500
# 4/4 [==============================] - 1s 187ms/step - loss: 0.8974 - accuracy: 0.8367 - val_loss: 1.5717 - val_accuracy: 0.5238
# Epoch 83/500
# 4/4 [==============================] - 0s 42ms/step - loss: 0.8852 - accuracy: 0.8367 - val_loss: 1.5700 - val_accuracy: 0.5238
# Epoch 84/500
# 4/4 [==============================] - 0s 54ms/step - loss: 0.8736 - accuracy: 0.8367 - val_loss: 1.5675 - val_accuracy: 0.5238
# Epoch 85/500
# 4/4 [==============================] - 0s 46ms/step - loss: 0.8626 - accuracy: 0.8367 - val_loss: 1.5661 - val_accuracy: 0.5238
# Epoch 86/500
# 4/4 [==============================] - 0s 33ms/step - loss: 0.8503 - accuracy: 0.8571 - val_loss: 1.5638 - val_accuracy: 0.5238
# Epoch 87/500
# 4/4 [==============================] - 0s 34ms/step - loss: 0.8395 - accuracy: 0.8571 - val_loss: 1.5575 - val_accuracy: 0.5238
# Epoch 88/500
# 4/4 [==============================] - 0s 33ms/step - loss: 0.8282 - accuracy: 0.8571 - val_loss: 1.5463 - val_accuracy: 0.5238
# Epoch 89/500
# 4/4 [==============================] - 0s 25ms/step - loss: 0.8178 - accuracy: 0.8571 - val_loss: 1.5382 - val_accuracy: 0.5714
# Epoch 90/500
# 4/4 [==============================] - 0s 97ms/step - loss: 0.8073 - accuracy: 0.8571 - val_loss: 1.5318 - val_accuracy: 0.5238
# Epoch 91/500
# 4/4 [==============================] - 1s 144ms/step - loss: 0.7965 - accuracy: 0.8571 - val_loss: 1.5283 - val_accuracy: 0.5238
# Epoch 92/500
# 4/4 [==============================] - 0s 40ms/step - loss: 0.7856 - accuracy: 0.8571 - val_loss: 1.5261 - val_accuracy: 0.5714
# Epoch 93/500
# 4/4 [==============================] - 0s 83ms/step - loss: 0.7751 - accuracy: 0.8571 - val_loss: 1.5256 - val_accuracy: 0.5714
# Epoch 94/500
# 4/4 [==============================] - 0s 40ms/step - loss: 0.7644 - accuracy: 0.8571 - val_loss: 1.5260 - val_accuracy: 0.5238
# Epoch 95/500
# 4/4 [==============================] - 0s 48ms/step - loss: 0.7543 - accuracy: 0.8571 - val_loss: 1.5256 - val_accuracy: 0.5238
# Epoch 96/500
# 4/4 [==============================] - 0s 29ms/step - loss: 0.7445 - accuracy: 0.8571 - val_loss: 1.5269 - val_accuracy: 0.5238
# Epoch 97/500
# 4/4 [==============================] - 0s 82ms/step - loss: 0.7353 - accuracy: 0.8571 - val_loss: 1.5261 - val_accuracy: 0.5238
# Epoch 98/500
# 4/4 [==============================] - 0s 51ms/step - loss: 0.7254 - accuracy: 0.8571 - val_loss: 1.5206 - val_accuracy: 0.5238
# Epoch 99/500
# 4/4 [==============================] - 0s 45ms/step - loss: 0.7149 - accuracy: 0.8571 - val_loss: 1.5113 - val_accuracy: 0.5238
# Epoch 100/500
# 4/4 [==============================] - 0s 34ms/step - loss: 0.7062 - accuracy: 0.8571 - val_loss: 1.5045 - val_accuracy: 0.5238
# Epoch 101/500
# 4/4 [==============================] - 0s 95ms/step - loss: 0.6967 - accuracy: 0.8776 - val_loss: 1.4983 - val_accuracy: 0.5238
# Epoch 102/500
# 4/4 [==============================] - 0s 55ms/step - loss: 0.6870 - accuracy: 0.8776 - val_loss: 1.4943 - val_accuracy: 0.5238
# Epoch 103/500
# 4/4 [==============================] - 0s 16ms/step - loss: 0.6787 - accuracy: 0.8776 - val_loss: 1.4910 - val_accuracy: 0.5238
# Epoch 104/500
# 4/4 [==============================] - 0s 29ms/step - loss: 0.6698 - accuracy: 0.8776 - val_loss: 1.4894 - val_accuracy: 0.5238
# Epoch 105/500
# 4/4 [==============================] - 0s 20ms/step - loss: 0.6620 - accuracy: 0.8776 - val_loss: 1.4864 - val_accuracy: 0.4762
# Epoch 106/500
# 4/4 [==============================] - 0s 42ms/step - loss: 0.6534 - accuracy: 0.8776 - val_loss: 1.4846 - val_accuracy: 0.4762
# Epoch 107/500
# 4/4 [==============================] - 0s 24ms/step - loss: 0.6449 - accuracy: 0.8776 - val_loss: 1.4820 - val_accuracy: 0.4762
# Epoch 108/500
# 4/4 [==============================] - 0s 33ms/step - loss: 0.6337 - accuracy: 0.8776 - val_loss: 1.4807 - val_accuracy: 0.5238
# Epoch 109/500
# 4/4 [==============================] - 0s 23ms/step - loss: 0.6254 - accuracy: 0.8776 - val_loss: 1.4817 - val_accuracy: 0.5714
# Epoch 110/500
# 4/4 [==============================] - 0s 39ms/step - loss: 0.6185 - accuracy: 0.8776 - val_loss: 1.4830 - val_accuracy: 0.5714
# Epoch 111/500
# 4/4 [==============================] - 0s 20ms/step - loss: 0.6101 - accuracy: 0.8776 - val_loss: 1.4808 - val_accuracy: 0.5714
# Epoch 112/500
# 4/4 [==============================] - 0s 19ms/step - loss: 0.6027 - accuracy: 0.8776 - val_loss: 1.4879 - val_accuracy: 0.5714
# Epoch 113/500
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5945 - accuracy: 0.8776 - val_loss: 1.4947 - val_accuracy: 0.5714
# Epoch 114/500
# 4/4 [==============================] - 0s 20ms/step - loss: 0.5867 - accuracy: 0.8776 - val_loss: 1.4992 - val_accuracy: 0.5714
# Epoch 115/500
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5799 - accuracy: 0.8776 - val_loss: 1.5005 - val_accuracy: 0.5714
# Epoch 116/500
# 4/4 [==============================] - 0s 22ms/step - loss: 0.5733 - accuracy: 0.8776 - val_loss: 1.4978 - val_accuracy: 0.5714
# Epoch 117/500
# 4/4 [==============================] - 0s 27ms/step - loss: 0.5660 - accuracy: 0.8776 - val_loss: 1.4942 - val_accuracy: 0.5238
# Epoch 118/500
# 4/4 [==============================] - 0s 18ms/step - loss: 0.5589 - accuracy: 0.8776 - val_loss: 1.4904 - val_accuracy: 0.5238
# Epoch 119/500
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5528 - accuracy: 0.8776 - val_loss: 1.4836 - val_accuracy: 0.5238
# Epoch 120/500
# 4/4 [==============================] - 0s 32ms/step - loss: 0.5453 - accuracy: 0.8776 - val_loss: 1.4752 - val_accuracy: 0.5714
# Epoch 121/500
# 4/4 [==============================] - 0s 20ms/step - loss: 0.5385 - accuracy: 0.8776 - val_loss: 1.4672 - val_accuracy: 0.5714
# Epoch 122/500
# 4/4 [==============================] - 0s 106ms/step - loss: 0.5314 - accuracy: 0.8776 - val_loss: 1.4631 - val_accuracy: 0.5714
# Epoch 123/500
# 4/4 [==============================] - 0s 52ms/step - loss: 0.5249 - accuracy: 0.8571 - val_loss: 1.4600 - val_accuracy: 0.5714
# Epoch 124/500
# 4/4 [==============================] - 0s 22ms/step - loss: 0.5188 - accuracy: 0.8571 - val_loss: 1.4593 - val_accuracy: 0.5714
# Epoch 125/500
# 4/4 [==============================] - 0s 61ms/step - loss: 0.5130 - accuracy: 0.8571 - val_loss: 1.4585 - val_accuracy: 0.5714
# Epoch 126/500
# 4/4 [==============================] - 0s 22ms/step - loss: 0.5073 - accuracy: 0.8776 - val_loss: 1.4582 - val_accuracy: 0.5714
# Epoch 127/500
# 4/4 [==============================] - 0s 20ms/step - loss: 0.5015 - accuracy: 0.8776 - val_loss: 1.4587 - val_accuracy: 0.5714
# Epoch 128/500
# 4/4 [==============================] - 0s 20ms/step - loss: 0.4961 - accuracy: 0.8776 - val_loss: 1.4610 - val_accuracy: 0.5238
# Epoch 129/500
# 4/4 [==============================] - 0s 27ms/step - loss: 0.4903 - accuracy: 0.8776 - val_loss: 1.4600 - val_accuracy: 0.5238
# Epoch 130/500
# 4/4 [==============================] - 0s 37ms/step - loss: 0.4845 - accuracy: 0.8776 - val_loss: 1.4534 - val_accuracy: 0.5238
# Epoch 131/500
# 4/4 [==============================] - 0s 46ms/step - loss: 0.4784 - accuracy: 0.8776 - val_loss: 1.4448 - val_accuracy: 0.5238
# Epoch 132/500
# 4/4 [==============================] - 0s 27ms/step - loss: 0.4727 - accuracy: 0.8776 - val_loss: 1.4304 - val_accuracy: 0.5238
# Epoch 133/500
# 4/4 [==============================] - 0s 29ms/step - loss: 0.4672 - accuracy: 0.8776 - val_loss: 1.4200 - val_accuracy: 0.5238
# Epoch 134/500
# 4/4 [==============================] - 0s 32ms/step - loss: 0.4616 - accuracy: 0.8776 - val_loss: 1.4135 - val_accuracy: 0.5238
# Epoch 135/500
# 4/4 [==============================] - 0s 24ms/step - loss: 0.4567 - accuracy: 0.8776 - val_loss: 1.4129 - val_accuracy: 0.5238
# Epoch 136/500
# 4/4 [==============================] - 0s 22ms/step - loss: 0.
500
# 4/4 [==============================] - 0s 33ms/step - loss: 0.3449 - accuracy: 0.8980 - val_loss: 1.4046 - val_accuracy: 0.5238
# Epoch 163/500
# 4/4 [==============================] - 0s 32ms/step - loss: 0.3410 - accuracy: 0.8980 - val_loss: 1.4042 - val_accuracy: 0.5238
# Epoch 164/500
# 4/4 [==============================] - 0s 32ms/step - loss: 0.3365 - accuracy: 0.8980 - val_loss: 1.4078 - val_accuracy: 0.5238
# Epoch 165/500
# 4/4 [==============================] - 0s 44ms/step - loss: 0.3336 - accuracy: 0.8980 - val_loss: 1.4113 - val_accuracy: 0.5238
# Epoch 166/500
# 4/4 [==============================] - 0s 63ms/step - loss: 0.3299 - accuracy: 0.8980 - val_loss: 1.4130 - val_accuracy: 0.5238
# Epoch 167/500
# 4/4 [==============================] - 0s 111ms/step - loss: 0.3263 - accuracy: 0.8980 - val_loss: 1.4129 - val_accuracy: 0.5238
# Epoch 168/500
# 4/4 [==============================] - 1s 360ms/step - loss: 0.3234 - accuracy: 0.8980 - val_loss: 1.4146 - val_accuracy: 0.5238
# Epoch 169/500
# 4/4 [==============================] - 0s 115ms/step - loss: 0.3204 - accuracy: 0.8776 - val_loss: 1.4169 - val_accuracy: 0.5238
# Epoch 170/500
# 4/4 [==============================] - 0s 45ms/step - loss: 0.3172 - accuracy: 0.8776 - val_loss: 1.4177 - val_accuracy: 0.5238
# Epoch 171/500
# 4/4 [==============================] - 0s 46ms/step - loss: 0.3140 - accuracy: 0.8776 - val_loss: 1.4134 - val_accuracy: 0.5238
# Epoch 172/500
# 4/4 [==============================] - 0s 44ms/step - loss: 0.3096 - accuracy: 0.8776 - val_loss: 1.4122 - val_accuracy: 0.5238
# Epoch 173/500
# 4/4 [==============================] - 0s 32ms/step - loss: 0.3065 - accuracy: 0.8776 - val_loss: 1.4108 - val_accuracy: 0.5238
# Epoch 174/500
# 4/4 [==============================] - 0s 35ms/step - loss: 0.3035 - accuracy: 0.8980 - val_loss: 1.4123 - val_accuracy: 0.5238
# Epoch 175/500
# 4/4 [==============================] - 0s 36ms/step - loss: 0.3008 - accuracy: 0.8980 - val_loss: 1.4144 - val_accuracy: 0.5238
# Epoch 176/500
# 4/4 [==============================] - 0s 49ms/step - loss: 0.2980 - accuracy: 0.9184 - val_loss: 1.4177 - val_accuracy: 0.5238
# Epoch 177/500
# 4/4 [==============================] - 0s 53ms/step - loss: 0.2953 - accuracy: 0.9184 - val_loss: 1.4208 - val_accuracy: 0.5238
# Epoch 178/500
# 4/4 [==============================] - 0s 38ms/step - loss: 0.2918 - accuracy: 0.9388 - val_loss: 1.4245 - val_accuracy: 0.5238
# Epoch 179/500
# 4/4 [==============================] - 0s 67ms/step - loss: 0.2894 - accuracy: 0.9388 - val_loss: 1.4312 - val_accuracy: 0.5238
# Epoch 180/500
# 4/4 [==============================] - 0s 60ms/step - loss: 0.2872 - accuracy: 0.9388 - val_loss: 1.4379 - val_accuracy: 0.5238
# Epoch 181/500
# 4/4 [==============================] - 0s 33ms/step - loss: 0.2835 - accuracy: 0.9388 - val_loss: 1.4455 - val_accuracy: 0.5238
# Epoch 182/500
# 4/4 [==============================] - 0s 35ms/step - loss: 0.2816 - accuracy: 0.9388 - val_loss: 1.4517 - val_accuracy: 0.5238
# Epoch 183/500
# 4/4 [==============================] - 0s 36ms/step - loss: 0.2781 - accuracy: 0.9388 - val_loss: 1.4570 - val_accuracy: 0.5238
# Epoch 184/500
# 4/4 [==============================] - 0s 37ms/step - loss: 0.2758 - accuracy: 0.9388 - val_loss: 1.4584 - val_accuracy: 0.5238
# Epoch 185/500
# 4/4 [==============================] - 0s 35ms/step - loss: 0.2733 - accuracy: 0.9388 - val_loss: 1.4599 - val_accuracy: 0.5238
# Epoch 186/500
# 4/4 [==============================] - 0s 30ms/step - loss: 0.2708 - accuracy: 0.9388 - val_loss: 1.4612 - val_accuracy: 0.5238
# Epoch 187/500
# 4/4 [==============================] - 0s 59ms/step - loss: 0.2686 - accuracy: 0.9388 - val_loss: 1.4617 - val_accuracy: 0.5238
# Epoch 188/500
# 4/4 [==============================] - 0s 36ms/step - loss: 0.2659 - accuracy: 0.9388 - val_loss: 1.4600 - val_accuracy: 0.5238
# Epoch 189/500
# 4/4 [==============================] - 0s 30ms/step - loss: 0.2638 - accuracy: 0.9388 - val_loss: 1.4576 - val_accuracy: 0.5238
# Epoch 190/500
# 4/4 [==============================] - 0s 20ms/step - loss: 0.2611 - accuracy: 0.9388 - val_loss: 1.4539 - val_accuracy: 0.5238
# Epoch 191/500
# 4/4 [==============================] - 0s 48ms/step - loss: 0.2589 - accuracy: 0.9388 - val_loss: 1.4483 - val_accuracy: 0.5238
# Epoch 192/500
# 4/4 [==============================] - 0s 33ms/step - loss: 0.2565 - accuracy: 0.9388 - val_loss: 1.4445 - val_accuracy: 0.5238
# Epoch 193/500
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2542 - accuracy: 0.9388 - val_loss: 1.4413 - val_accuracy: 0.5238
# CPU times: user 12.9 s, sys: 1.36 s, total: 14.3 s
# Wall time: 38 s

# %% [markdown]
# 🧑🏻‍🏫 **Remarks**
#
#
# - 📉 The model continues to converge even though its Loss Function had some consecutive loss increases/decreases w.r.t. to the number of epochs
# - 🤷🏻‍♂️ The `patience` number to select is highly related to the task at hand, and there is no general rule of thumb
# - 🧑🏻‍🏫 If you selected a high patience value for your Early Stopping:
#     - 🤞 your Neural Network should theoretically still stop training before the end (not always the case if your number of epochs is too low)
#     - ❗️ your validation loss will increase again after reaching a minimum value, but ideally, you want it to be as low as possible; the validation loss potentially reaches a minimum for certain weights at a certain epoch
#         - 🤔 How to find these weights?
#
# 📚 The `EarlyStopping` criterion enables you to:
# - stop the convergence
# - restore the best weights of the NN when it had the lowest error level (or the best score) on the validation set, thanks to `restore_best_weights = True` (set to `False` by default)

# %% [markdown]
# ##### Restoring the Best Weights of a Model
#
# - Run the model with an Early Stopping criterion that will restore the best weights of the Neural Net
# - Plot the loss and accuracy
# - Print the accuracy on the testing set

# %%
# YOUR CODE HERE

# %% [markdown]
# 🥡 **Takeaways from the Early Stopping criterion:**
#
# - You can look at the 📚 [**Early Stopping documentation**](https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/EarlyStopping) to play with other parameters
# - You no longer need to have a look at the number of epochs as long as the model hits the stopping criterion. So, in the future, you should set a large number of epochs and the Early Stopping criterion will take care of stopping the training procedure before the model overfits!

# %% [markdown]
# ### (2.2) Batch Size & Epochs
#
# 🕵️‍♀️ Let's investigate the impact of the batch size on training a Neural Network and how we can use it to control how fast the parameters are updated.

# %% [markdown]
# #### Playing with the Batch Size
#
# Let's run the previous model with **different batch sizes** (with the Early Stopping criterion included) and plot the results.
#
# 👉 Run the following cell

# %%
# %%time
# RUN THIS CELL
es = EarlyStopping(patience=20, restore_best_weights=True)

for batch_size in [1, 4, 32]:
    
    model = initialize_model()

    history = model.fit(
        X_train_scaled,
        y_train,
        validation_split = 0.3,
        epochs = 500,
        batch_size = batch_size, 
        verbose = 0, 
        callbacks = [es]
    )

    results = model.evaluate(X_test_scaled, y_test, verbose=0)
    plot_loss_accuracy(history, title=f'------ BATCH SIZE {batch_size} ------\n The accuracy on the test set is of {results[1]:.2f}')
# Out:
# CPU times: user 26.7 s, sys: 2.64 s, total: 29.4 s
# Wall time: 46.8 s

# %% [markdown]
# #### ❓Question: Impact of the Batch Size on the Convergence of a Neural Network
#
# Look at the oscillations of the accuracy and the loss according to the batch size number.
#
# Is this coherent with what we saw when playing with the TensorFlow Playground?

# %% [markdown]
# > Your answer here

# %% [markdown]
# #### ❓Question: Number of Parameter Updates
#
# How many weight optimizations are done within one epoch (considering the number of observations and the batch size)? Does one epoch have more weight updates with a large or with a small batch size?

# %% [markdown]
# > Your answer here

# %% [markdown]
# #### Explanations
#
# Copy and paste this code into a new cell, run it, and observe.
#
# ```python
# print(f"There are {X_train.shape[0]} rows in the training set")
#
# batch_size = 16
# epochs = 2
#
# model = initialize_model()
#
# history = model.fit(
#     X_train_scaled,
#     y_train,
#     validation_split = 0.3,
#     epochs = epochs,
#     batch_size = batch_size,
#     verbose = 1
# )
# ```
#
#
# <u><b>Number of parameter updates:</b></u>
#
# - There are 1400 rows in the training set:
#     - $ 70 \% \times 1400 = 980 $ rows are used as the training set within the training set
#     - $ 30 \% \times 1400 = 420 $ rows are used as the validation set
# - For each epoch, we run a forward/backward propagation $ \large \lceil \frac{980}{batch size} \rceil = \lceil \frac{980}{16}\rceil = 62$ times
# - Without the Early Stopping Criterion, we will have _number of_ $ epochs \times 62 = 2 \times 62 = 124 $ iterations overall
#
# <u><b>Impact of the batch size:</b></u>
#
# The smaller the batch size
#
# $ \implies $ The more sub-iterations will be done
# $ \implies $ Parameters will be updated more frequently
# $ \implies $ We may need fewer epochs
#
# _(but we also don't care too much about the number of epochs if we use an Early Stopping Criterion with a patience term anyway)_

# %%
batch_size = 16
epochs = 2

model = initialize_model()

history = model.fit(
    X_train_scaled, 
    y_train,
    validation_split = 0.3,
    epochs = epochs,
    batch_size = batch_size, 
    verbose = 1
)
# Out:
# Epoch 1/2
# 4/4 [==============================] - 2s 128ms/step - loss: 2.0482 - accuracy: 0.1429 - val_loss: 2.1381 - val_accuracy: 0.2857
# Epoch 2/2
# 4/4 [==============================] - 0s 18ms/step - loss: 2.0123 - accuracy: 0.1633 - val_loss: 2.1251 - val_accuracy: 0.2857

# %% [markdown]
# ### (2.3) Regularization
#
# ❗️**Neural Networks with complex architectures can quickly lead to overfitting** (_too many layers and/or neurons_)❗️
#
# 🔥 But since Dense Neural Networks are just activated linear regressions, the weights can be constrained using L1, L2, or L1-L2 penalties!
#
# 🚓 So, let's apply some L2 or L1 penalties to these neurons; as in Machine Learning, these penalties are called **`Regularizers`**.
#
# 📚 <a href="https://www.tensorflow.org/api_docs/python/tf/keras/regularizers">See `tf.keras.regularizers`</a>

# %% [markdown]
# #### Observing Overfitting Before Regularizing
#
# First, let's initialize a model that has too many parameters for the task such that it overfits the training data quickly. To that purpose, let's not use any Early Stopping criterion.
#
# 🎁 Let's not waste time re-coding something that you are now used to, just run the following cell and observe what is happening 👇

# %%
# RUN THIS CELL

# 1. Model Architecture
model = models.Sequential()
model.add(layers.Dense(25, activation='relu', input_dim=10))
model.add(layers.Dense(10, activation='relu'))
model.add(layers.Dense(8, activation='softmax'))

# 2. Model Compilation
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# 3. Training 
history = model.fit(
    X_train_scaled,
    y_train,
    validation_split = 0.3,
    epochs = 300,           # Notice that we are not using any Early Stopping Criterion
    batch_size = 16, 
    verbose=0
)

# 4. Evaluation
results_train = model.evaluate(X_train_scaled, y_train, verbose = 0)
results_test = model.evaluate(X_test_scaled, y_test, verbose = 0)


# 5. Looking back at what happened during the training phase
print(f'The accuracy on the testing set is {results_test[1]:.2f}...')
print(f'...whereas the accuracy on the training set is {results_train[1]:.2f}!')
plot_loss_accuracy(history)
# Out:
# The accuracy on the testing set is 0.70...
# ...whereas the accuracy on the training set is 0.87!

# %% [markdown]
# ☝️ In our "over-parameterized network", some neurons became **too specific for the given training data**, preventing the network from generalizing to new data.
#
# 😕 This led to some overfitting!

# %% [markdown]
# #### Studying the Impact of Regularization on the Neural Network
#
# Change the previous code to integrate an L2 or L1 regularizer into your Dense Layers.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### (2.4) Dropout Layers

# %% [markdown]
# #### Introduction to Dropout Layers
#
# The role of a Dropout Layer is to randomly cancel the output of some neurons during the training phase, it prevents the network from getting too specific for the input data.
#
# Dropout Layers
# - ensure that no neuron can overspecialize in learning a pattern of the dataset because its output is sometimes canceled
# - force the information of an input to be spread across multiple neurons instead of only one specific neuron
# - are super straightforward to code 👌
#   - but what is going on _under the hood_? 👩🏻‍🏫

# %% [markdown]
# #### Optional Reading
#
# <details>
#     <summary>Click here for further explanations about Dropout Layers</summary>
#
# 🤔 Remember what we said about neurons becoming **too specific**?
#
# **`BEGIN_EXPLANATIONS_ABOUT_DROPOUT_LAYERS`**
#
# ---
#
# ⚽️  **A Football Analogy:**
#
# Think about a football team. There are 11 players on the pitch, but there are also players on the bench. Why?
# - The coach may want to substitute injured or tired players during the game
# - The team may be
#     - losing the game and willing to substitute a midfielder with a more **versatile player** who can be more offensive (= **mix of** midfielder/attacker roles)
#     - winning the game and would like to secure the result by replacing a midfielder with a more **versatile player** who can be more defensive (= **mix of** midfielder/defense roles)
#
# 💡 Well, in a Neural Net, there is also a risk that a neuron over-specializes in detecting one pattern, where it would be advisable to keep it more versatile.
#
# ---
#
# 📚 **The goal of [Dropout Layers](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dropout) is to prevent neurons from over-specializing.**
#
# 🧑🏻‍🏫 How do Dropout Layers work?
#
# 👉 When we apply a **Dropout rate** of 20% to a layer $k$, 20% of the **selected neurons** will have their weights **temporarily set to 0** , which has the following consequences:
# 1. A neuron computed at layer $k + 1$ considers all the weights as usual, but since some of them were temporarily set to 0, they were “ignored” while creating the neurons of this layer $k + 1$
# 2. Once a batch of data points has been seen by the Neural Network (**forward propagation**) and 80% of the weights in a layer have been optimized/updated (**backward propagation** with the **Adam** optimizer), the Neural Network moves on to the forward propagation of the next batch, where it will use:
#    - 80% of the weights; the ones that were updated
#    - 20% of the weights; the ones that were previously ignored and had their values **temporarily** set to 0
#
# Based on these weights, we will go through this Dropout Layer again, which is going to temporarily ignore another 20% of the weights of a given layer. Be careful, the selection of this 20% is random, so the weights that will be ignored this time won't necessarily be the same as before!
#
# 👉 Think about the **Dropout rate** as a **sampling with replacement**
#
# 👉 By **randomly shutting down** different neurons at different epochs, we force the data points to be **analyzed by different neurons**. At the end of the day, these neurons will become **more versatile** instead of over-specializing!
#
# ---
#
# **`END_EXPLANATIONS_ABOUT_DROPOUT_LAYERS`**
# </details>

# %% [markdown]
# #### Studying the Impact of Dropout Layers on the Neural Network
#
# Include some Dropout layers in the architecture of your original model _(don't add regularizers here)_.
#
# What can you observe regarding the convergence of your model? What about its ability to generalize?

# %%
# YOUR CODE HERE

# %% [markdown]
# ## (3) Conclusions
#
# - ❗️ If you train a Neural Network too much (too many layers, too many neurons, and/or too many epochs), it will overfit very quickly
# - 🥊 To prevent overfitting in Deep Learning, you can use Early Stopping, Regularization, and Dropout Layers
# - ❗️ Be careful, if you use these techniques, you might end up on the other spectrum of the performance where your model would underfit the dataset!
# - 🆗 You could potentially look at the batch size but we usually use 16 or 32; and as the French Computer Scientist [**Yann Lecun**](https://en.wikipedia.org/wiki/Yann_LeCun) said (Facebook x NYU):
#
# <img src="https://wagon-public-datasets.s3.amazonaws.com/data-science-images/DL/deep_learning_yann_lecun_batch_size.png" alt="batch_size_yann_lecun" width="500">

# %% [markdown]
# ## 🏁 Congratulations!
#
# 💾 Do not forget to `git add/commit/push` your notebook...
#
# 🚀 ... and move to the next challenge!

# %%
git add .
git commit -m"review 1.3.2"
git push origin master
# Out:
#   Cell In [98], line 1
#     git add .
#         ^
# SyntaxError: invalid syntax
